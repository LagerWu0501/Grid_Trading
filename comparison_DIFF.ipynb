# %%
import numpy as np
import pandas as pd
import Strategies 
import Strategy_Analysis_Tool 
from binance.client import Client
from matplotlib import pyplot as plt

# %%
# Get data
symbol = "BTCUSDT"
timeFrame = "1h"
startDate = "2017-01-01"
endDate = "2022-08-28"
client = Client()
bars = client.get_historical_klines(symbol=symbol,interval=timeFrame,start_str=startDate, end_str = endDate)
df = pd.DataFrame(bars[:],columns=["timestamp","open","high","low","close","volume", "close_time", "quote_asset_volume", "number_of_trade", "TBB", "TBQ", "ignore"])
df["date"]=pd.to_datetime(df["timestamp"],unit="ms").astype(str)
df = df.drop(["timestamp", "close_time", "quote_asset_volume", "number_of_trade", "TBB", "TBQ", "ignore"], axis=1)
df["open"] = pd.to_numeric(df["open"])
df["high"] = pd.to_numeric(df["high"])
df["low"] = pd.to_numeric(df["low"])
df["close"] = pd.to_numeric(df["close"])
df["volume"] = pd.to_numeric(df["volume"])
df
# Out:
#            open      high       low     close       volume  \
# 0       4261.48   4313.62   4261.32   4308.83    47.181009
# 1       4308.83   4328.69   4291.37   4315.32    23.234916
# 2       4330.29   4345.45   4309.37   4324.35     7.229691
# 3       4316.62   4349.99   4287.41   4349.99     4.443249
# 4       4333.32   4377.85   4333.32   4360.69     0.972807
# ...         ...       ...       ...       ...          ...
# 43953  20018.00  20040.40  19941.83  20007.99  4374.049180
# 43954  20007.99  20029.84  19870.01  19873.06  2779.324280
# 43955  19874.25  20103.57  19858.43  20020.08  8501.926530
# 43956  20021.35  20087.65  19992.55  20037.60  5025.547650
# 43957  20037.60  20051.22  19926.78  19992.16  5346.543810
#
#                       date
# 0      2017-08-17 04:00:00
# 1      2017-08-17 05:00:00
# 2      2017-08-17 06:00:00
# 3      2017-08-17 07:00:00
# 4      2017-08-17 08:00:00
# ...                    ...
# 43953  2022-08-27 20:00:00
# 43954  2022-08-27 21:00:00
# 43955  2022-08-27 22:00:00
# 43956  2022-08-27 23:00:00
# 43957  2022-08-28 00:00:00
#
# [43958 rows x 6 columns]

# %%
# Grid strategy
grid_parameters = {
    "name":"grid",                                    ## str
    "start_money" : 1000.0,                           ## float    
    "start_storage" : 0.0,                            ## float
    "trading_fee_rate" : 0.002,                       ## float
    "unit" : 0.005,                                   ## float
    "grid_number" : 20,                               ## int  
    "equal_Diff_or_Ratio" : "RATIO",                  ## "DIFF", "RATIO"
    "trading_logistic":"both",                        ## "long", "short", "both"
    "initial_setup":{"type":"None", "portion":0.0},   ## "type": "long", "short" or "None". "portion" : float
    "lowest_price" : 1.0,                             ## float
    "highest_price" : 60000.0                         ## float
}
myGrid = Strategies.Grid(grid_parameters)
# Buy and hold
buy_and_hold_parameters = {
    "name":"buy and hold",                            ## str
    "start_money" : 1000.0,                           ## float    
    "start_storage" : 0.0,                            ## float
    "trading_fee_rate" : 0.002,                       ## float
    "unit" : 0.0001,                                  ## float
}
buy_and_hodl = Strategies.Buy_and_Hold(buy_and_hold_parameters)

# %%
sharpe_ratio, expected_return = Strategy_Analysis_Tool.Analysis_tool.Shape_Ratio(myGrid, df, 0.02, window_size=10000, window_off=1000)
print("*--------------------------------*")
print("strategy:", myGrid.name)
print("expected return:", expected_return * 100)
print("sharpe ratio:", sharpe_ratio)
sharpe_ratio, expected_return = Strategy_Analysis_Tool.Analysis_tool.Shape_Ratio(buy_and_hodl, df, 0.02, window_size=10000, window_off=1000)
print("*--------------------------------*")
print("strategy:", buy_and_hodl.name)
print("expected return:", expected_return * 100)
print("sharpe ratio:", sharpe_ratio)

profit, trading_count, buy_record, sell_record, MDD = myGrid.back_test(df)
print("*--------------------------------*")
print("strategy:", myGrid.name)
print("trading count:", trading_count)
print("profit:", profit * 100)
print("MDD:", MDD)
profit, trading_count, buy_record, sell_record, MDD = buy_and_hodl.back_test(df)
print("*--------------------------------*")
print("strategy:", buy_and_hodl.name)
print("trading count:", trading_count)
print("profit:", profit * 100)
print("MDD:", MDD)
# Out:
# *--------------------------------*
# strategy: grid
# expected return: 7.761034560884977
# sharpe ratio: 0.22050978590443993
# *--------------------------------*
# strategy: buy and hold
# expected return: 121.7750752080959
# sharpe ratio: 0.6863524542570872
# *--------------------------------*
# strategy: grid
# trading count: 18
# profit: 4.204703949015425
# MDD: 0.39898075507949926
# *--------------------------------*
# strategy: buy and hold
# trading count: 2
# profit: 369.1365441114355
# MDD: 0.957469866475196

# %% [markdown]
# ## Brute Force and find the best parameters

# %%
# Buy and hold
buy_and_hold_parameters = {
    "name":"buy and hold",                            ## str
    "start_money" : 1000.0,                           ## float    
    "start_storage" : 0.0,                            ## float
    "trading_fee_rate" : 0.002,                       ## float
    "unit" : 0.0001,                                  ## float
}
buy_and_hodl = Strategies.Buy_and_Hold(buy_and_hold_parameters)
sharpe_ratio, expected_return = Strategy_Analysis_Tool.Analysis_tool.Shape_Ratio(buy_and_hodl, df, 0.02, window_size=10000, window_off=1000)
print("*--------------------------------*")
print("strategy:", buy_and_hodl.name)
print("expected return:", expected_return * 100)
print("sharpe ratio:", sharpe_ratio)
# Out:
# *--------------------------------*
# strategy: buy and hold
# expected return: 121.7750752080959
# sharpe ratio: 0.6863524542570872

# %%
grid_parameters = {
    "name":"grid",                                    ## str
    "start_money" : 1000.0,                           ## float    
    "start_storage" : 0.0,                            ## float
    "trading_fee_rate" : 0.002,                       ## float
    "unit" : 0.005,                                   ## float
    "grid_number" : 20,                               ## int  
    "equal_Diff_or_Ratio" : "DIFF",                   ## "DIFF", "RATIO"
    "trading_logistic":"both",                        ## "long", "short", "both"
    "initial_setup":{"type":"None", "portion":0.0},   ## "type": "long", "short" or "None". "portion" : float
    "lowest_price" : 1.0,                             ## float
    "highest_price" : 60000.0                         ## float
}

index = 0
sharpe = []
expected = []
for unit in range(1, 10501, 500):
    for grid_number in range(20, 40, 2):
        for lowest_price in range(1, 10000, 2000):
            for highest_price in range(40000, 60000, 2000):
                grid_parameters["unit"] = unit/100000
                grid_parameters["grid_number"] = grid_number
                grid_parameters["lowest_price"] = lowest_price
                grid_parameters["highest_price"] = highest_price

                myGrid = Strategies.Grid(grid_parameters)
                sharpe_ratio, expected_return = Strategy_Analysis_Tool.Analysis_tool.Shape_Ratio(myGrid, df, 0.02, window_size=10000, window_off=1000)
                print("*--------------------------------*")
                print("index:", index)
                print("unit:", unit)
                print("grid number:", grid_number)
                print("lowest price:", lowest_price)
                print("highest price:", highest_price)
                print("strategy:", myGrid.name)
                print("expected return:", expected_return * 100)
                print("sharpe ratio:", sharpe_ratio)
                sharpe.append(sharpe_ratio)
                expected.append(expected_return)
                index += 1
# Out:
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 1
# highest price: 40000
# strategy: grid
# expected return: 0.24426380283231242
# sharpe ratio: -2.6321213442453497
# *--------------------------------*
# index: 1
# unit: 1
# grid number: 20
# lowest price: 1
# highest price: 42000
# strategy: grid
# expected return: 0.20833552479998318
# sharpe ratio: -2.715504616705055
# *--------------------------------*
# index: 2
# unit: 1
# grid number: 20
# lowest price: 1
# highest price: 44000
# strategy: grid
# expected return: 0.2015532462030057
# sharpe ratio: -2.5907309623214103
# *--------------------------------*
# index: 3
# unit: 1
# grid number: 20
# lowest price: 1
# highest price: 46000
# strategy: grid
# expected return: 0.16880412264704017
# sharpe ratio: -2.7668334228119775
# *--------------------------------*
# index: 4
# unit: 1
# grid number: 20
# lowest price: 1
# highest price: 48000
# strategy: grid
# expected return: 0.15126589527062606
# sharpe ratio: -2.854877560672647
# *--------------------------------*
# index: 5
# unit: 1
# grid number: 20
# lowest price: 1
# highest price: 50000
# strategy: grid
# expected return: 0.10188189199703689
# sharpe ratio: -2.9421111861521356
# *--------------------------------*
# index: 6
# unit: 1
# grid number: 20
# lowest price: 1
# highest price: 52000
# strategy: grid
# expected return: 0.057436431232374005
# sharpe ratio: -2.8033060807077717
# *--------------------------------*
# index: 7
# unit: 1
# grid number: 20
# lowest price: 1
# highest price: 54000
# strategy: grid
# expected return: 0.06504265928234107
# sharpe ratio: -2.9688994403006204
# *--------------------------------*
# index: 8
# unit: 1
# grid number: 20
# lowest price: 1
# highest price: 56000
# strategy: grid
# expected return: 0.016228215220612307
# sharpe ratio: -2.992250943144815
# *--------------------------------*
# index: 9
# unit: 1
# grid number: 20
# lowest price: 1
# highest price: 58000
# strategy: grid
# expected return: -0.02742376379118475
# sharpe ratio: -3.5083629677315327
# *--------------------------------*
# index: 10
# unit: 1
# grid number: 20
# lowest price: 2001
# highest price: 40000
# strategy: grid
# expected return: 0.2879063996235134
# sharpe ratio: -2.176650808457907
# *--------------------------------*
# index: 11
# unit: 1
# grid number: 20
# lowest price: 2001
# highest price: 42000
# strategy: grid
# expected return: 0.23432074223822932
# sharpe ratio: -2.5068125134613095
# *--------------------------------*
# index: 12
# unit: 1
# grid number: 20
# lowest price: 2001
# highest price: 44000
# strategy: grid
# expected return: 0.1993563856705738
# sharpe ratio: -2.471440878160841
# *--------------------------------*
# index: 13
# unit: 1
# grid number: 20
# lowest price: 2001
# highest price: 46000
# strategy: grid
# expected return: 0.18700158288539562
# sharpe ratio: -2.4932758989034514
# *--------------------------------*
# index: 14
# unit: 1
# grid number: 20
# lowest price: 2001
# highest price: 48000
# strategy: grid
# expected return: 0.1662241332617411
# sharpe ratio: -2.562910092023401
# *--------------------------------*
# index: 15
# unit: 1
# grid number: 20
# lowest price: 2001
# highest price: 50000
# strategy: grid
# expected return: 0.12526391190005548
# sharpe ratio: -2.498616498359039
# *--------------------------------*
# index: 16
# unit: 1
# grid number: 20
# lowest price: 2001
# highest price: 52000
# strategy: grid
# expected return: 0.07018390904115841
# sharpe ratio: -2.658320330594733
# *--------------------------------*
# index: 17
# unit: 1
# grid number: 20
# lowest price: 2001
# highest price: 54000
# strategy: grid
# expected return: 0.07218687330879178
# sharpe ratio: -2.88757284832552
# *--------------------------------*
# index: 18
# unit: 1
# grid number: 20
# lowest price: 2001
# highest price: 56000
# strategy: grid
# expected return: 0.01668831602055433
# sharpe ratio: -3.031460453210754
# *--------------------------------*
# index: 19
# unit: 1
# grid number: 20
# lowest price: 2001
# highest price: 58000
# strategy: grid
# expected return: -0.017314097635306447
# sharpe ratio: -2.812727627164848
# *--------------------------------*
# index: 20
# unit: 1
# grid number: 20
# lowest price: 4001
# highest price: 40000
# strategy: grid
# expected return: 0.2626373138559138
# sharpe ratio: -2.2769171526164333
# *--------------------------------*
# index: 21
# unit: 1
# grid number: 20
# lowest price: 4001
# highest price: 42000
# strategy: grid
# expected return: 0.2725503021411819
# sharpe ratio: -2.1239233412282403
# *--------------------------------*
# index: 22
# unit: 1
# grid number: 20
# lowest price: 4001
# highest price: 44000
# strategy: grid
# expected return: 0.21614109898234296
# sharpe ratio: -2.3356657186895946
# *--------------------------------*
# index: 23
# unit: 1
# grid number: 20
# lowest price: 4001
# highest price: 46000
# strategy: grid
# expected return: 0.2033763209294113
# sharpe ratio: -2.329521307223874
# *--------------------------------*
# index: 24
# unit: 1
# grid number: 20
# lowest price: 4001
# highest price: 48000
# strategy: grid
# expected return: 0.15875858685596225
# sharpe ratio: -2.418177673179922
# *--------------------------------*
# index: 25
# unit: 1
# grid number: 20
# lowest price: 4001
# highest price: 50000
# strategy: grid
# expected return: 0.10433216599999438
# sharpe ratio: -2.583672666137028
# *--------------------------------*
# index: 26
# unit: 1
# grid number: 20
# lowest price: 4001
# highest price: 52000
# strategy: grid
# expected return: 0.08040406646174827
# sharpe ratio: -2.614736654636758
# *--------------------------------*
# index: 27
# unit: 1
# grid number: 20
# lowest price: 4001
# highest price: 54000
# strategy: grid
# expected return: 0.045534670473535446
# sharpe ratio: -2.7437557322646917
# *--------------------------------*
# index: 28
# unit: 1
# grid number: 20
# lowest price: 4001
# highest price: 56000
# strategy: grid
# expected return: 0.021028944073507583
# sharpe ratio: -2.7402137358624725
# *--------------------------------*
# index: 29
# unit: 1
# grid number: 20
# lowest price: 4001
# highest price: 58000
# strategy: grid
# expected return: -0.03592609047650681
# sharpe ratio: -2.76148954548361
# *--------------------------------*
# index: 30
# unit: 1
# grid number: 20
# lowest price: 6001
# highest price: 40000
# strategy: grid
# expected return: 0.2884917597617356
# sharpe ratio: -1.9815959870708846
# *--------------------------------*
# index: 31
# unit: 1
# grid number: 20
# lowest price: 6001
# highest price: 42000
# strategy: grid
# expected return: 0.2532681808824417
# sharpe ratio: -2.1525066734045377
# *--------------------------------*
# index: 32
# unit: 1
# grid number: 20
# lowest price: 6001
# highest price: 44000
# strategy: grid
# expected return: 0.24472128973532076
# sharpe ratio: -2.0643133041470585
# *--------------------------------*
# index: 33
# unit: 1
# grid number: 20
# lowest price: 6001
# highest price: 46000
# strategy: grid
# expected return: 0.20204829242943131
# sharpe ratio: -2.199863134505452
# *--------------------------------*
# index: 34
# unit: 1
# grid number: 20
# lowest price: 6001
# highest price: 48000
# strategy: grid
# expected return: 0.1900138599529642
# sharpe ratio: -2.122971985279567
# *--------------------------------*
# index: 35
# unit: 1
# grid number: 20
# lowest price: 6001
# highest price: 50000
# strategy: grid
# expected return: 0.12065860136767062
# sharpe ratio: -2.1756062776055005
# *--------------------------------*
# index: 36
# unit: 1
# grid number: 20
# lowest price: 6001
# highest price: 52000
# strategy: grid
# expected return: 0.08208764789117542
# sharpe ratio: -2.490192715270286
# *--------------------------------*
# index: 37
# unit: 1
# grid number: 20
# lowest price: 6001
# highest price: 54000
# strategy: grid
# expected return: 0.043820696832367424
# sharpe ratio: -2.34852505410795
# *--------------------------------*
# index: 38
# unit: 1
# grid number: 20
# lowest price: 6001
# highest price: 56000
# strategy: grid
# expected return: -0.0008058654999986717
# sharpe ratio: -2.660245160037518
# *--------------------------------*
# index: 39
# unit: 1
# grid number: 20
# lowest price: 6001
# highest price: 58000
# strategy: grid
# expected return: -0.05109120145299724
# sharpe ratio: -2.78173622364976
# *--------------------------------*
# index: 40
# unit: 1
# grid number: 20
# lowest price: 8001
# highest price: 40000
# strategy: grid
# expected return: 0.2993537615764293
# sharpe ratio: -1.8674414607975396
# *--------------------------------*
# index: 41
# unit: 1
# grid number: 20
# lowest price: 8001
# highest price: 42000
# strategy: grid
# expected return: 0.2723703397117443
# sharpe ratio: -1.9388427169259086
# *--------------------------------*
# index: 42
# unit: 1
# grid number: 20
# lowest price: 8001
# highest price: 44000
# strategy: grid
# expected return: 0.2418635484060213
# sharpe ratio: -1.9097938387056297
# *--------------------------------*
# index: 43
# unit: 1
# grid number: 20
# lowest price: 8001
# highest price: 46000
# strategy: grid
# expected return: 0.1882983695852843
# sharpe ratio: -2.162704553714566
# *--------------------------------*
# index: 44
# unit: 1
# grid number: 20
# lowest price: 8001
# highest price: 48000
# strategy: grid
# expected return: 0.17450348660886142
# sharpe ratio: -2.094622406318521
# *--------------------------------*
# index: 45
# unit: 1
# grid number: 20
# lowest price: 8001
# highest price: 50000
# strategy: grid
# expected return: 0.12462934820586413
# sharpe ratio: -2.038600545853186
# *--------------------------------*
# index: 46
# unit: 1
# grid number: 20
# lowest price: 8001
# highest price: 52000
# strategy: grid
# expected return: 0.11171566343527589
# sharpe ratio: -2.1800715510929893
# *--------------------------------*
# index: 47
# unit: 1
# grid number: 20
# lowest price: 8001
# highest price: 54000
# strategy: grid
# expected return: 0.04757393802062681
# sharpe ratio: -2.288167036673185
# *--------------------------------*
# index: 48
# unit: 1
# grid number: 20
# lowest price: 8001
# highest price: 56000
# strategy: grid
# expected return: 0.016885336458828466
# sharpe ratio: -2.3107080688640775
# *--------------------------------*
# index: 49
# unit: 1
# grid number: 20
# lowest price: 8001
# highest price: 58000
# strategy: grid
# expected return: -0.0028029505999935408
# sharpe ratio: -2.4318108222170034
# *--------------------------------*
# index: 50
# unit: 1
# grid number: 22
# lowest price: 1
# highest price: 40000
# strategy: grid
# expected return: 0.26419441513369496
# sharpe ratio: -2.2756054187825705
# *--------------------------------*
# index: 51
# unit: 1
# grid number: 22
# lowest price: 1
# highest price: 42000
# strategy: grid
# expected return: 0.27554533436088285
# sharpe ratio: -2.119149492652228
# *--------------------------------*
# index: 52
# unit: 1
# grid number: 22
# lowest price: 1
# highest price: 44000
# strategy: grid
# expected return: 0.21614257867370698
# sharpe ratio: -2.335663187611612
# *--------------------------------*
# index: 53
# unit: 1
# grid number: 22
# lowest price: 1
# highest price: 46000
# strategy: grid
# expected return: 0.20645130976202963
# sharpe ratio: -2.261231946427594
# *--------------------------------*
# index: 54
# unit: 1
# grid number: 22
# lowest price: 1
# highest price: 48000
# strategy: grid
# expected return: 0.18078912144113532
# sharpe ratio: -2.3202586870467434
# *--------------------------------*
# index: 55
# unit: 1
# grid number: 22
# lowest price: 1
# highest price: 50000
# strategy: grid
# expected return: 0.12682401818985842
# sharpe ratio: -2.405323689384113
# *--------------------------------*
# index: 56
# unit: 1
# grid number: 22
# lowest price: 1
# highest price: 52000
# strategy: grid
# expected return: 0.12516343523263276
# sharpe ratio: -2.3697072622187356
# *--------------------------------*
# index: 57
# unit: 1
# grid number: 22
# lowest price: 1
# highest price: 54000
# strategy: grid
# expected return: 0.05552496364706719
# sharpe ratio: -2.5081497755426927
# *--------------------------------*
# index: 58
# unit: 1
# grid number: 22
# lowest price: 1
# highest price: 56000
# strategy: grid
# expected return: 0.03415259956681113
# sharpe ratio: -2.5054135812744183
# *--------------------------------*
# index: 59
# unit: 1
# grid number: 22
# lowest price: 1
# highest price: 58000
# strategy: grid
# expected return: -0.02499092932353184
# sharpe ratio: -2.673993365002706
# *--------------------------------*
# index: 60
# unit: 1
# grid number: 22
# lowest price: 2001
# highest price: 40000
# strategy: grid
# expected return: 0.3129711446738076
# sharpe ratio: -1.968077999060212
# *--------------------------------*
# index: 61
# unit: 1
# grid number: 22
# lowest price: 2001
# highest price: 42000
# strategy: grid
# expected return: 0.2580135406951663
# sharpe ratio: -2.1478885535469554
# *--------------------------------*
# index: 62
# unit: 1
# grid number: 22
# lowest price: 2001
# highest price: 44000
# strategy: grid
# expected return: 0.24891120959619475
# sharpe ratio: -2.045428940834907
# *--------------------------------*
# index: 63
# unit: 1
# grid number: 22
# lowest price: 2001
# highest price: 46000
# strategy: grid
# expected return: 0.20384559088763113
# sharpe ratio: -2.1988909399950107
# *--------------------------------*
# index: 64
# unit: 1
# grid number: 22
# lowest price: 2001
# highest price: 48000
# strategy: grid
# expected return: 0.17372654408549254
# sharpe ratio: -2.2189501787190453
# *--------------------------------*
# index: 65
# unit: 1
# grid number: 22
# lowest price: 2001
# highest price: 50000
# strategy: grid
# expected return: 0.12767806178874722
# sharpe ratio: -2.1629904250532217
# *--------------------------------*
# index: 66
# unit: 1
# grid number: 22
# lowest price: 2001
# highest price: 52000
# strategy: grid
# expected return: 0.08972333240906412
# sharpe ratio: -2.494361554791874
# *--------------------------------*
# index: 67
# unit: 1
# grid number: 22
# lowest price: 2001
# highest price: 54000
# strategy: grid
# expected return: 0.05877309344119996
# sharpe ratio: -2.345533969923468
# *--------------------------------*
# index: 68
# unit: 1
# grid number: 22
# lowest price: 2001
# highest price: 56000
# strategy: grid
# expected return: 0.019473103558854128
# sharpe ratio: -2.4497773416087263
# *--------------------------------*
# index: 69
# unit: 1
# grid number: 22
# lowest price: 2001
# highest price: 58000
# strategy: grid
# expected return: -0.017308970310251866
# sharpe ratio: -2.5364920858584634
# *--------------------------------*
# index: 70
# unit: 1
# grid number: 22
# lowest price: 4001
# highest price: 40000
# strategy: grid
# expected return: 0.3162677722807614
# sharpe ratio: -1.850366206143531
# *--------------------------------*
# index: 71
# unit: 1
# grid number: 22
# lowest price: 4001
# highest price: 42000
# strategy: grid
# expected return: 0.2836888966123304
# sharpe ratio: -1.89785596235858
# *--------------------------------*
# index: 72
# unit: 1
# grid number: 22
# lowest price: 4001
# highest price: 44000
# strategy: grid
# expected return: 0.23400089256149953
# sharpe ratio: -2.008550552513636
# *--------------------------------*
# index: 73
# unit: 1
# grid number: 22
# lowest price: 4001
# highest price: 46000
# strategy: grid
# expected return: 0.21401268168983098
# sharpe ratio: -2.0367648724544845
# *--------------------------------*
# index: 74
# unit: 1
# grid number: 22
# lowest price: 4001
# highest price: 48000
# strategy: grid
# expected return: 0.1853792752325747
# sharpe ratio: -2.0641093857236346
# *--------------------------------*
# index: 75
# unit: 1
# grid number: 22
# lowest price: 4001
# highest price: 50000
# strategy: grid
# expected return: 0.1486061351630761
# sharpe ratio: -1.9286984146428936
# *--------------------------------*
# index: 76
# unit: 1
# grid number: 22
# lowest price: 4001
# highest price: 52000
# strategy: grid
# expected return: 0.09902744806417448
# sharpe ratio: -2.1634534914243537
# *--------------------------------*
# index: 77
# unit: 1
# grid number: 22
# lowest price: 4001
# highest price: 54000
# strategy: grid
# expected return: 0.047569392433170196
# sharpe ratio: -2.313509723494837
# *--------------------------------*
# index: 78
# unit: 1
# grid number: 22
# lowest price: 4001
# highest price: 56000
# strategy: grid
# expected return: 0.012758344935874747
# sharpe ratio: -2.3435583384179473
# *--------------------------------*
# index: 79
# unit: 1
# grid number: 22
# lowest price: 4001
# highest price: 58000
# strategy: grid
# expected return: -0.02828301485293423
# sharpe ratio: -2.528938847272567
# *--------------------------------*
# index: 80
# unit: 1
# grid number: 22
# lowest price: 6001
# highest price: 40000
# strategy: grid
# expected return: 0.35113114620047786
# sharpe ratio: -1.6294752452187107
# *--------------------------------*
# index: 81
# unit: 1
# grid number: 22
# lowest price: 6001
# highest price: 42000
# strategy: grid
# expected return: 0.31521570434494195
# sharpe ratio: -1.7065211597371106
# *--------------------------------*
# index: 82
# unit: 1
# grid number: 22
# lowest price: 6001
# highest price: 44000
# strategy: grid
# expected return: 0.2383325344732792
# sharpe ratio: -1.8321969072214956
# *--------------------------------*
# index: 83
# unit: 1
# grid number: 22
# lowest price: 6001
# highest price: 46000
# strategy: grid
# expected return: 0.23544049721929075
# sharpe ratio: -1.7358582073334325
# *--------------------------------*
# index: 84
# unit: 1
# grid number: 22
# lowest price: 6001
# highest price: 48000
# strategy: grid
# expected return: 0.19753569358020337
# sharpe ratio: -1.865309875923374
# *--------------------------------*
# index: 85
# unit: 1
# grid number: 22
# lowest price: 6001
# highest price: 50000
# strategy: grid
# expected return: 0.13546197509356528
# sharpe ratio: -1.9252383764768537
# *--------------------------------*
# index: 86
# unit: 1
# grid number: 22
# lowest price: 6001
# highest price: 52000
# strategy: grid
# expected return: 0.11538172521924184
# sharpe ratio: -1.9045640794485912
# *--------------------------------*
# index: 87
# unit: 1
# grid number: 22
# lowest price: 6001
# highest price: 54000
# strategy: grid
# expected return: 0.0813724163128477
# sharpe ratio: -2.115995922025326
# *--------------------------------*
# index: 88
# unit: 1
# grid number: 22
# lowest price: 6001
# highest price: 56000
# strategy: grid
# expected return: -0.015813768606903623
# sharpe ratio: -2.114021318961488
# *--------------------------------*
# index: 89
# unit: 1
# grid number: 22
# lowest price: 6001
# highest price: 58000
# strategy: grid
# expected return: -0.017348743989295454
# sharpe ratio: -2.2300232808472105
# *--------------------------------*
# index: 90
# unit: 1
# grid number: 22
# lowest price: 8001
# highest price: 40000
# strategy: grid
# expected return: 0.41523395438233357
# sharpe ratio: -1.3259374802879444
# *--------------------------------*
# index: 91
# unit: 1
# grid number: 22
# lowest price: 8001
# highest price: 42000
# strategy: grid
# expected return: 0.35428924933957384
# sharpe ratio: -1.4309210350156072
# *--------------------------------*
# index: 92
# unit: 1
# grid number: 22
# lowest price: 8001
# highest price: 44000
# strategy: grid
# expected return: 0.2995802968047696
# sharpe ratio: -1.491145072920079
# *--------------------------------*
# index: 93
# unit: 1
# grid number: 22
# lowest price: 8001
# highest price: 46000
# strategy: grid
# expected return: 0.2582691290347016
# sharpe ratio: -1.6093839728264894
# *--------------------------------*
# index: 94
# unit: 1
# grid number: 22
# lowest price: 8001
# highest price: 48000
# strategy: grid
# expected return: 0.2162180044064863
# sharpe ratio: -1.6795761899229977
# *--------------------------------*
# index: 95
# unit: 1
# grid number: 22
# lowest price: 8001
# highest price: 50000
# strategy: grid
# expected return: 0.1102422833341955
# sharpe ratio: -1.882016744024107
# *--------------------------------*
# index: 96
# unit: 1
# grid number: 22
# lowest price: 8001
# highest price: 52000
# strategy: grid
# expected return: 0.10020612429145954
# sharpe ratio: -1.8953633463340172
# *--------------------------------*
# index: 97
# unit: 1
# grid number: 22
# lowest price: 8001
# highest price: 54000
# strategy: grid
# expected return: 0.07447836612836509
# sharpe ratio: -1.9669311012394683
# *--------------------------------*
# index: 98
# unit: 1
# grid number: 22
# lowest price: 8001
# highest price: 56000
# strategy: grid
# expected return: 0.028384500494705808
# sharpe ratio: -1.986512792157077
# *--------------------------------*
# index: 99
# unit: 1
# grid number: 22
# lowest price: 8001
# highest price: 58000
# strategy: grid
# expected return: -0.021749672288755437
# sharpe ratio: -2.0058289293699434
# *--------------------------------*
# index: 100
# unit: 1
# grid number: 24
# lowest price: 1
# highest price: 40000
# strategy: grid
# expected return: 0.34672789008823274
# sharpe ratio: -1.7859374678479885
# *--------------------------------*
# index: 101
# unit: 1
# grid number: 24
# lowest price: 1
# highest price: 42000
# strategy: grid
# expected return: 0.2938985258161782
# sharpe ratio: -1.9177060302441362
# *--------------------------------*
# index: 102
# unit: 1
# grid number: 24
# lowest price: 1
# highest price: 44000
# strategy: grid
# expected return: 0.23416963377204408
# sharpe ratio: -2.0249343027554545
# *--------------------------------*
# index: 103
# unit: 1
# grid number: 24
# lowest price: 1
# highest price: 46000
# strategy: grid
# expected return: 0.21956405433096104
# sharpe ratio: -2.0143609522706707
# *--------------------------------*
# index: 104
# unit: 1
# grid number: 24
# lowest price: 1
# highest price: 48000
# strategy: grid
# expected return: 0.18538088528676336
# sharpe ratio: -2.064107047654261
# *--------------------------------*
# index: 105
# unit: 1
# grid number: 24
# lowest price: 1
# highest price: 50000
# strategy: grid
# expected return: 0.1410399082794567
# sharpe ratio: -1.9568599232054857
# *--------------------------------*
# index: 106
# unit: 1
# grid number: 24
# lowest price: 1
# highest price: 52000
# strategy: grid
# expected return: 0.0974050611176551
# sharpe ratio: -2.147609677034083
# *--------------------------------*
# index: 107
# unit: 1
# grid number: 24
# lowest price: 1
# highest price: 54000
# strategy: grid
# expected return: 0.058502289897043466
# sharpe ratio: -2.3261166284712944
# *--------------------------------*
# index: 108
# unit: 1
# grid number: 24
# lowest price: 1
# highest price: 56000
# strategy: grid
# expected return: 0.02615244383826273
# sharpe ratio: -2.212014601861054
# *--------------------------------*
# index: 109
# unit: 1
# grid number: 24
# lowest price: 1
# highest price: 58000
# strategy: grid
# expected return: -0.016485129838276037
# sharpe ratio: -2.45756513136882
# *--------------------------------*
# index: 110
# unit: 1
# grid number: 24
# lowest price: 2001
# highest price: 40000
# strategy: grid
# expected return: 0.3514424564632453
# sharpe ratio: -1.6786209814363515
# *--------------------------------*
# index: 111
# unit: 1
# grid number: 24
# lowest price: 2001
# highest price: 42000
# strategy: grid
# expected return: 0.3068298898088237
# sharpe ratio: -1.7668992373403087
# *--------------------------------*
# index: 112
# unit: 1
# grid number: 24
# lowest price: 2001
# highest price: 44000
# strategy: grid
# expected return: 0.27294633030148613
# sharpe ratio: -1.7499886456914835
# *--------------------------------*
# index: 113
# unit: 1
# grid number: 24
# lowest price: 2001
# highest price: 46000
# strategy: grid
# expected return: 0.22327507572060906
# sharpe ratio: -1.829088594578694
# *--------------------------------*
# index: 114
# unit: 1
# grid number: 24
# lowest price: 2001
# highest price: 48000
# strategy: grid
# expected return: 0.19702585986774335
# sharpe ratio: -1.923995859406534
# *--------------------------------*
# index: 115
# unit: 1
# grid number: 24
# lowest price: 2001
# highest price: 50000
# strategy: grid
# expected return: 0.13725940552202107
# sharpe ratio: -1.9239015319741235
# *--------------------------------*
# index: 116
# unit: 1
# grid number: 24
# lowest price: 2001
# highest price: 52000
# strategy: grid
# expected return: 0.12601145216178458
# sharpe ratio: -1.8788177201598497
# *--------------------------------*
# index: 117
# unit: 1
# grid number: 24
# lowest price: 2001
# highest price: 54000
# strategy: grid
# expected return: 0.08799690458822891
# sharpe ratio: -2.0451190198420464
# *--------------------------------*
# index: 118
# unit: 1
# grid number: 24
# lowest price: 2001
# highest price: 56000
# strategy: grid
# expected return: 0.0022023928602386365
# sharpe ratio: -2.1409667499154064
# *--------------------------------*
# index: 119
# unit: 1
# grid number: 24
# lowest price: 2001
# highest price: 58000
# strategy: grid
# expected return: -0.03763736228676346
# sharpe ratio: -2.149979923436479
# *--------------------------------*
# index: 120
# unit: 1
# grid number: 24
# lowest price: 4001
# highest price: 40000
# strategy: grid
# expected return: 0.39476595943387954
# sharpe ratio: -1.4616070531863543
# *--------------------------------*
# index: 121
# unit: 1
# grid number: 24
# lowest price: 4001
# highest price: 42000
# strategy: grid
# expected return: 0.3685632682719305
# sharpe ratio: -1.4624449502260695
# *--------------------------------*
# index: 122
# unit: 1
# grid number: 24
# lowest price: 4001
# highest price: 44000
# strategy: grid
# expected return: 0.3342439244632163
# sharpe ratio: -1.4637193783472273
# *--------------------------------*
# index: 123
# unit: 1
# grid number: 24
# lowest price: 4001
# highest price: 46000
# strategy: grid
# expected return: 0.22804167185292787
# sharpe ratio: -1.7269853456570226
# *--------------------------------*
# index: 124
# unit: 1
# grid number: 24
# lowest price: 4001
# highest price: 48000
# strategy: grid
# expected return: 0.22546496061765592
# sharpe ratio: -1.6794082744274332
# *--------------------------------*
# index: 125
# unit: 1
# grid number: 24
# lowest price: 4001
# highest price: 50000
# strategy: grid
# expected return: 0.14694629083814845
# sharpe ratio: -1.754920658528708
# *--------------------------------*
# index: 126
# unit: 1
# grid number: 24
# lowest price: 4001
# highest price: 52000
# strategy: grid
# expected return: 0.11108205261027404
# sharpe ratio: -1.8699619829068
# *--------------------------------*
# index: 127
# unit: 1
# grid number: 24
# lowest price: 4001
# highest price: 54000
# strategy: grid
# expected return: 0.1107015628161304
# sharpe ratio: -1.7980093159775363
# *--------------------------------*
# index: 128
# unit: 1
# grid number: 24
# lowest price: 4001
# highest price: 56000
# strategy: grid
# expected return: 0.006542229389745715
# sharpe ratio: -2.023323937726973
# *--------------------------------*
# index: 129
# unit: 1
# grid number: 24
# lowest price: 4001
# highest price: 58000
# strategy: grid
# expected return: -0.05255372711033268
# sharpe ratio: -2.07279167774124
# *--------------------------------*
# index: 130
# unit: 1
# grid number: 24
# lowest price: 6001
# highest price: 40000
# strategy: grid
# expected return: 0.41169548929408967
# sharpe ratio: -1.3521132854155988
# *--------------------------------*
# index: 131
# unit: 1
# grid number: 24
# lowest price: 6001
# highest price: 42000
# strategy: grid
# expected return: 0.39369173725012674
# sharpe ratio: -1.314567240776847
# *--------------------------------*
# index: 132
# unit: 1
# grid number: 24
# lowest price: 6001
# highest price: 44000
# strategy: grid
# expected return: 0.33626687267637095
# sharpe ratio: -1.3668615541634004
# *--------------------------------*
# index: 133
# unit: 1
# grid number: 24
# lowest price: 6001
# highest price: 46000
# strategy: grid
# expected return: 0.2914253692426434
# sharpe ratio: -1.4326594038782186
# *--------------------------------*
# index: 134
# unit: 1
# grid number: 24
# lowest price: 6001
# highest price: 48000
# strategy: grid
# expected return: 0.2353806473381974
# sharpe ratio: -1.5430307707252302
# *--------------------------------*
# index: 135
# unit: 1
# grid number: 24
# lowest price: 6001
# highest price: 50000
# strategy: grid
# expected return: 0.17002673944860575
# sharpe ratio: -1.5768011900405465
# *--------------------------------*
# index: 136
# unit: 1
# grid number: 24
# lowest price: 6001
# highest price: 52000
# strategy: grid
# expected return: 0.09467755455139214
# sharpe ratio: -1.8261028198503886
# *--------------------------------*
# index: 137
# unit: 1
# grid number: 24
# lowest price: 6001
# highest price: 54000
# strategy: grid
# expected return: 0.08204644369119578
# sharpe ratio: -1.839526195338689
# *--------------------------------*
# index: 138
# unit: 1
# grid number: 24
# lowest price: 6001
# highest price: 56000
# strategy: grid
# expected return: 0.018589415029393146
# sharpe ratio: -1.8382823713073413
# *--------------------------------*
# index: 139
# unit: 1
# grid number: 24
# lowest price: 6001
# highest price: 58000
# strategy: grid
# expected return: -0.028894295198542825
# sharpe ratio: -1.923026071243113
# *--------------------------------*
# index: 140
# unit: 1
# grid number: 24
# lowest price: 8001
# highest price: 40000
# strategy: grid
# expected return: 0.4234165888455795
# sharpe ratio: -1.2528099075859862
# *--------------------------------*
# index: 141
# unit: 1
# grid number: 24
# lowest price: 8001
# highest price: 42000
# strategy: grid
# expected return: 0.4008285472352869
# sharpe ratio: -1.2092417151597346
# *--------------------------------*
# index: 142
# unit: 1
# grid number: 24
# lowest price: 8001
# highest price: 44000
# strategy: grid
# expected return: 0.30171712992664146
# sharpe ratio: -1.411787731167386
# *--------------------------------*
# index: 143
# unit: 1
# grid number: 24
# lowest price: 8001
# highest price: 46000
# strategy: grid
# expected return: 0.2539178165661179
# sharpe ratio: -1.427748694072465
# *--------------------------------*
# index: 144
# unit: 1
# grid number: 24
# lowest price: 8001
# highest price: 48000
# strategy: grid
# expected return: 0.2337945251029496
# sharpe ratio: -1.3902568204271915
# *--------------------------------*
# index: 145
# unit: 1
# grid number: 24
# lowest price: 8001
# highest price: 50000
# strategy: grid
# expected return: 0.17022755311030388
# sharpe ratio: -1.3998277538612751
# *--------------------------------*
# index: 146
# unit: 1
# grid number: 24
# lowest price: 8001
# highest price: 52000
# strategy: grid
# expected return: 0.12136390571325882
# sharpe ratio: -1.5873925916055827
# *--------------------------------*
# index: 147
# unit: 1
# grid number: 24
# lowest price: 8001
# highest price: 54000
# strategy: grid
# expected return: 0.05373086411027379
# sharpe ratio: -1.7668179464063887
# *--------------------------------*
# index: 148
# unit: 1
# grid number: 24
# lowest price: 8001
# highest price: 56000
# strategy: grid
# expected return: 0.003973642544140339
# sharpe ratio: -1.8033027349388537
# *--------------------------------*
# index: 149
# unit: 1
# grid number: 24
# lowest price: 8001
# highest price: 58000
# strategy: grid
# expected return: -0.0515861295220739
# sharpe ratio: -1.7936778900132724
# *--------------------------------*
# index: 150
# unit: 1
# grid number: 26
# lowest price: 1
# highest price: 40000
# strategy: grid
# expected return: 0.3686981923279712
# sharpe ratio: -1.5781339846467684
# *--------------------------------*
# index: 151
# unit: 1
# grid number: 26
# lowest price: 1
# highest price: 42000
# strategy: grid
# expected return: 0.3385338134864152
# sharpe ratio: -1.5763306259295435
# *--------------------------------*
# index: 152
# unit: 1
# grid number: 26
# lowest price: 1
# highest price: 44000
# strategy: grid
# expected return: 0.301571766597288
# sharpe ratio: -1.6266152407527568
# *--------------------------------*
# index: 153
# unit: 1
# grid number: 26
# lowest price: 1
# highest price: 46000
# strategy: grid
# expected return: 0.25670411593894754
# sharpe ratio: -1.6651432404718296
# *--------------------------------*
# index: 154
# unit: 1
# grid number: 26
# lowest price: 1
# highest price: 48000
# strategy: grid
# expected return: 0.2102638347692415
# sharpe ratio: -1.7309823179490724
# *--------------------------------*
# index: 155
# unit: 1
# grid number: 26
# lowest price: 1
# highest price: 50000
# strategy: grid
# expected return: 0.150160165246618
# sharpe ratio: -1.7510784662159993
# *--------------------------------*
# index: 156
# unit: 1
# grid number: 26
# lowest price: 1
# highest price: 52000
# strategy: grid
# expected return: 0.11108379770363098
# sharpe ratio: -1.8699599612911417
# *--------------------------------*
# index: 157
# unit: 1
# grid number: 26
# lowest price: 1
# highest price: 54000
# strategy: grid
# expected return: 0.09957395626698559
# sharpe ratio: -1.8296136223239525
# *--------------------------------*
# index: 158
# unit: 1
# grid number: 26
# lowest price: 1
# highest price: 56000
# strategy: grid
# expected return: 0.004063812927647097
# sharpe ratio: -2.0093332324285957
# *--------------------------------*
# index: 159
# unit: 1
# grid number: 26
# lowest price: 1
# highest price: 58000
# strategy: grid
# expected return: -0.05333815719455069
# sharpe ratio: -2.0153063198877845
# *--------------------------------*
# index: 160
# unit: 1
# grid number: 26
# lowest price: 2001
# highest price: 40000
# strategy: grid
# expected return: 0.4290830014117462
# sharpe ratio: -1.3300889415105264
# *--------------------------------*
# index: 161
# unit: 1
# grid number: 26
# lowest price: 2001
# highest price: 42000
# strategy: grid
# expected return: 0.3654974411515685
# sharpe ratio: -1.4301758904486064
# *--------------------------------*
# index: 162
# unit: 1
# grid number: 26
# lowest price: 2001
# highest price: 44000
# strategy: grid
# expected return: 0.34015604640272346
# sharpe ratio: -1.4411742132353484
# *--------------------------------*
# index: 163
# unit: 1
# grid number: 26
# lowest price: 2001
# highest price: 46000
# strategy: grid
# expected return: 0.30117546079184726
# sharpe ratio: -1.4803502046484165
# *--------------------------------*
# index: 164
# unit: 1
# grid number: 26
# lowest price: 2001
# highest price: 48000
# strategy: grid
# expected return: 0.21624797310407823
# sharpe ratio: -1.6334668543138615
# *--------------------------------*
# index: 165
# unit: 1
# grid number: 26
# lowest price: 2001
# highest price: 50000
# strategy: grid
# expected return: 0.1783080743598051
# sharpe ratio: -1.5936947451848273
# *--------------------------------*
# index: 166
# unit: 1
# grid number: 26
# lowest price: 2001
# highest price: 52000
# strategy: grid
# expected return: 0.12000478689365615
# sharpe ratio: -1.7424012567939595
# *--------------------------------*
# index: 167
# unit: 1
# grid number: 26
# lowest price: 2001
# highest price: 54000
# strategy: grid
# expected return: 0.08384400236655952
# sharpe ratio: -1.838067898160676
# *--------------------------------*
# index: 168
# unit: 1
# grid number: 26
# lowest price: 2001
# highest price: 56000
# strategy: grid
# expected return: 0.03789715173309108
# sharpe ratio: -1.7584954942282183
# *--------------------------------*
# index: 169
# unit: 1
# grid number: 26
# lowest price: 2001
# highest price: 58000
# strategy: grid
# expected return: -0.03413746228506276
# sharpe ratio: -1.9257124308412663
# *--------------------------------*
# index: 170
# unit: 1
# grid number: 26
# lowest price: 4001
# highest price: 40000
# strategy: grid
# expected return: 0.4212192693619118
# sharpe ratio: -1.3080690935093924
# *--------------------------------*
# index: 171
# unit: 1
# grid number: 26
# lowest price: 4001
# highest price: 42000
# strategy: grid
# expected return: 0.36785254141177104
# sharpe ratio: -1.3534362371304682
# *--------------------------------*
# index: 172
# unit: 1
# grid number: 26
# lowest price: 4001
# highest price: 44000
# strategy: grid
# expected return: 0.32680852510853475
# sharpe ratio: -1.4192655773724143
# *--------------------------------*
# index: 173
# unit: 1
# grid number: 26
# lowest price: 4001
# highest price: 46000
# strategy: grid
# expected return: 0.28754940867424983
# sharpe ratio: -1.431274629039625
# *--------------------------------*
# index: 174
# unit: 1
# grid number: 26
# lowest price: 4001
# highest price: 48000
# strategy: grid
# expected return: 0.2427868443077416
# sharpe ratio: -1.422213301291576
# *--------------------------------*
# index: 175
# unit: 1
# grid number: 26
# lowest price: 4001
# highest price: 50000
# strategy: grid
# expected return: 0.17320787279183428
# sharpe ratio: -1.5001835849350462
# *--------------------------------*
# index: 176
# unit: 1
# grid number: 26
# lowest price: 4001
# highest price: 52000
# strategy: grid
# expected return: 0.15215487405434008
# sharpe ratio: -1.562279267117901
# *--------------------------------*
# index: 177
# unit: 1
# grid number: 26
# lowest price: 4001
# highest price: 54000
# strategy: grid
# expected return: 0.06242328222856148
# sharpe ratio: -1.7927290738982622
# *--------------------------------*
# index: 178
# unit: 1
# grid number: 26
# lowest price: 4001
# highest price: 56000
# strategy: grid
# expected return: 0.014849691828096496
# sharpe ratio: -1.7803128885648423
# *--------------------------------*
# index: 179
# unit: 1
# grid number: 26
# lowest price: 4001
# highest price: 58000
# strategy: grid
# expected return: -0.050407734929884866
# sharpe ratio: -1.7564733278244187
# *--------------------------------*
# index: 180
# unit: 1
# grid number: 26
# lowest price: 6001
# highest price: 40000
# strategy: grid
# expected return: 0.4440309789004569
# sharpe ratio: -1.1947678336911438
# *--------------------------------*
# index: 181
# unit: 1
# grid number: 26
# lowest price: 6001
# highest price: 42000
# strategy: grid
# expected return: 0.41257936472851064
# sharpe ratio: -1.1965099904501622
# *--------------------------------*
# index: 182
# unit: 1
# grid number: 26
# lowest price: 6001
# highest price: 44000
# strategy: grid
# expected return: 0.3691667167941438
# sharpe ratio: -1.2335497096416375
# *--------------------------------*
# index: 183
# unit: 1
# grid number: 26
# lowest price: 6001
# highest price: 46000
# strategy: grid
# expected return: 0.27331080192309665
# sharpe ratio: -1.3472616912031994
# *--------------------------------*
# index: 184
# unit: 1
# grid number: 26
# lowest price: 6001
# highest price: 48000
# strategy: grid
# expected return: 0.2242975596810237
# sharpe ratio: -1.4190554642428144
# *--------------------------------*
# index: 185
# unit: 1
# grid number: 26
# lowest price: 6001
# highest price: 50000
# strategy: grid
# expected return: 0.1604400455430166
# sharpe ratio: -1.4605682782606688
# *--------------------------------*
# index: 186
# unit: 1
# grid number: 26
# lowest price: 6001
# highest price: 52000
# strategy: grid
# expected return: 0.15086430743217072
# sharpe ratio: -1.3765313464796733
# *--------------------------------*
# index: 187
# unit: 1
# grid number: 26
# lowest price: 6001
# highest price: 54000
# strategy: grid
# expected return: 0.09959920977607843
# sharpe ratio: -1.5537323485907812
# *--------------------------------*
# index: 188
# unit: 1
# grid number: 26
# lowest price: 6001
# highest price: 56000
# strategy: grid
# expected return: -0.003127868828035814
# sharpe ratio: -1.6905853866308334
# *--------------------------------*
# index: 189
# unit: 1
# grid number: 26
# lowest price: 6001
# highest price: 58000
# strategy: grid
# expected return: -0.07799003884384773
# sharpe ratio: -1.7120131640691345
# *--------------------------------*
# index: 190
# unit: 1
# grid number: 26
# lowest price: 8001
# highest price: 40000
# strategy: grid
# expected return: 0.5151636344547396
# sharpe ratio: -0.9799670500726623
# *--------------------------------*
# index: 191
# unit: 1
# grid number: 26
# lowest price: 8001
# highest price: 42000
# strategy: grid
# expected return: 0.44011927394119477
# sharpe ratio: -1.0569150935666884
# *--------------------------------*
# index: 192
# unit: 1
# grid number: 26
# lowest price: 8001
# highest price: 44000
# strategy: grid
# expected return: 0.3699783004457204
# sharpe ratio: -1.1515244709481216
# *--------------------------------*
# index: 193
# unit: 1
# grid number: 26
# lowest price: 8001
# highest price: 46000
# strategy: grid
# expected return: 0.3295770852647261
# sharpe ratio: -1.138156733473245
# *--------------------------------*
# index: 194
# unit: 1
# grid number: 26
# lowest price: 8001
# highest price: 48000
# strategy: grid
# expected return: 0.2800682238937718
# sharpe ratio: -1.2335649759970266
# *--------------------------------*
# index: 195
# unit: 1
# grid number: 26
# lowest price: 8001
# highest price: 50000
# strategy: grid
# expected return: 0.16717634486196786
# sharpe ratio: -1.3123139888172786
# *--------------------------------*
# index: 196
# unit: 1
# grid number: 26
# lowest price: 8001
# highest price: 52000
# strategy: grid
# expected return: 0.08869025986202946
# sharpe ratio: -1.459855019552782
# *--------------------------------*
# index: 197
# unit: 1
# grid number: 26
# lowest price: 8001
# highest price: 54000
# strategy: grid
# expected return: 0.08212769837103742
# sharpe ratio: -1.4605213191123725
# *--------------------------------*
# index: 198
# unit: 1
# grid number: 26
# lowest price: 8001
# highest price: 56000
# strategy: grid
# expected return: -0.00587668597056732
# sharpe ratio: -1.5333289884209098
# *--------------------------------*
# index: 199
# unit: 1
# grid number: 26
# lowest price: 8001
# highest price: 58000
# strategy: grid
# expected return: -0.11555284146606971
# sharpe ratio: -1.6319957461086836
# *--------------------------------*
# index: 200
# unit: 1
# grid number: 28
# lowest price: 1
# highest price: 40000
# strategy: grid
# expected return: 0.43116205568906396
# sharpe ratio: -1.3249248729577123
# *--------------------------------*
# index: 201
# unit: 1
# grid number: 28
# lowest price: 1
# highest price: 42000
# strategy: grid
# expected return: 0.4054459565902235
# sharpe ratio: -1.296526787210638
# *--------------------------------*
# index: 202
# unit: 1
# grid number: 28
# lowest price: 1
# highest price: 44000
# strategy: grid
# expected return: 0.320369141733247
# sharpe ratio: -1.4314335477847826
# *--------------------------------*
# index: 203
# unit: 1
# grid number: 28
# lowest price: 1
# highest price: 46000
# strategy: grid
# expected return: 0.2854197056576531
# sharpe ratio: -1.4387818493185294
# *--------------------------------*
# index: 204
# unit: 1
# grid number: 28
# lowest price: 1
# highest price: 48000
# strategy: grid
# expected return: 0.2723969881471413
# sharpe ratio: -1.4138937152993012
# *--------------------------------*
# index: 205
# unit: 1
# grid number: 28
# lowest price: 1
# highest price: 50000
# strategy: grid
# expected return: 0.17338498836759797
# sharpe ratio: -1.54398657349628
# *--------------------------------*
# index: 206
# unit: 1
# grid number: 28
# lowest price: 1
# highest price: 52000
# strategy: grid
# expected return: 0.14453778420804006
# sharpe ratio: -1.5713154290943299
# *--------------------------------*
# index: 207
# unit: 1
# grid number: 28
# lowest price: 1
# highest price: 54000
# strategy: grid
# expected return: 0.07883130230667681
# sharpe ratio: -1.7435581068931179
# *--------------------------------*
# index: 208
# unit: 1
# grid number: 28
# lowest price: 1
# highest price: 56000
# strategy: grid
# expected return: 0.014851556571482804
# sharpe ratio: -1.7803111539937782
# *--------------------------------*
# index: 209
# unit: 1
# grid number: 28
# lowest price: 1
# highest price: 58000
# strategy: grid
# expected return: -0.0491898143550165
# sharpe ratio: -1.699267640751129
# *--------------------------------*
# index: 210
# unit: 1
# grid number: 28
# lowest price: 2001
# highest price: 40000
# strategy: grid
# expected return: 0.455164674071387
# sharpe ratio: -1.212325248217102
# *--------------------------------*
# index: 211
# unit: 1
# grid number: 28
# lowest price: 2001
# highest price: 42000
# strategy: grid
# expected return: 0.4165232059138759
# sharpe ratio: -1.2211908679431627
# *--------------------------------*
# index: 212
# unit: 1
# grid number: 28
# lowest price: 2001
# highest price: 44000
# strategy: grid
# expected return: 0.32144355772887984
# sharpe ratio: -1.3772146986006992
# *--------------------------------*
# index: 213
# unit: 1
# grid number: 28
# lowest price: 2001
# highest price: 46000
# strategy: grid
# expected return: 0.3259567055903731
# sharpe ratio: -1.251487794864824
# *--------------------------------*
# index: 214
# unit: 1
# grid number: 28
# lowest price: 2001
# highest price: 48000
# strategy: grid
# expected return: 0.24067166799382933
# sharpe ratio: -1.4396309095342352
# *--------------------------------*
# index: 215
# unit: 1
# grid number: 28
# lowest price: 2001
# highest price: 50000
# strategy: grid
# expected return: 0.18110329232357503
# sharpe ratio: -1.4055918425442702
# *--------------------------------*
# index: 216
# unit: 1
# grid number: 28
# lowest price: 2001
# highest price: 52000
# strategy: grid
# expected return: 0.12133292033609502
# sharpe ratio: -1.4579757929613182
# *--------------------------------*
# index: 217
# unit: 1
# grid number: 28
# lowest price: 2001
# highest price: 54000
# strategy: grid
# expected return: 0.11655291581716437
# sharpe ratio: -1.5242513246110934
# *--------------------------------*
# index: 218
# unit: 1
# grid number: 28
# lowest price: 2001
# highest price: 56000
# strategy: grid
# expected return: 0.005163385119722583
# sharpe ratio: -1.6732207699801425
# *--------------------------------*
# index: 219
# unit: 1
# grid number: 28
# lowest price: 2001
# highest price: 58000
# strategy: grid
# expected return: -0.0761923618003336
# sharpe ratio: -1.7103812567643237
# *--------------------------------*
# index: 220
# unit: 1
# grid number: 28
# lowest price: 4001
# highest price: 40000
# strategy: grid
# expected return: 0.47657254940330895
# sharpe ratio: -1.1172092811175993
# *--------------------------------*
# index: 221
# unit: 1
# grid number: 28
# lowest price: 4001
# highest price: 42000
# strategy: grid
# expected return: 0.43078728378362086
# sharpe ratio: -1.1286725528094836
# *--------------------------------*
# index: 222
# unit: 1
# grid number: 28
# lowest price: 4001
# highest price: 44000
# strategy: grid
# expected return: 0.4116342684727279
# sharpe ratio: -1.0941275523081262
# *--------------------------------*
# index: 223
# unit: 1
# grid number: 28
# lowest price: 4001
# highest price: 46000
# strategy: grid
# expected return: 0.32402057589700956
# sharpe ratio: -1.2149783395750884
# *--------------------------------*
# index: 224
# unit: 1
# grid number: 28
# lowest price: 4001
# highest price: 48000
# strategy: grid
# expected return: 0.2905300281660135
# sharpe ratio: -1.257254117619468
# *--------------------------------*
# index: 225
# unit: 1
# grid number: 28
# lowest price: 4001
# highest price: 50000
# strategy: grid
# expected return: 0.17257442804640544
# sharpe ratio: -1.3804676702848602
# *--------------------------------*
# index: 226
# unit: 1
# grid number: 28
# lowest price: 4001
# highest price: 52000
# strategy: grid
# expected return: 0.11511883716173357
# sharpe ratio: -1.404477068561391
# *--------------------------------*
# index: 227
# unit: 1
# grid number: 28
# lowest price: 4001
# highest price: 54000
# strategy: grid
# expected return: 0.10665628559026659
# sharpe ratio: -1.3989088487984664
# *--------------------------------*
# index: 228
# unit: 1
# grid number: 28
# lowest price: 4001
# highest price: 56000
# strategy: grid
# expected return: 0.010076581747887626
# sharpe ratio: -1.5480458403663988
# *--------------------------------*
# index: 229
# unit: 1
# grid number: 28
# lowest price: 4001
# highest price: 58000
# strategy: grid
# expected return: -0.10197357901263532
# sharpe ratio: -1.6153248706195007
# *--------------------------------*
# index: 230
# unit: 1
# grid number: 28
# lowest price: 6001
# highest price: 40000
# strategy: grid
# expected return: 0.5351849124411382
# sharpe ratio: -0.9334879734418304
# *--------------------------------*
# index: 231
# unit: 1
# grid number: 28
# lowest price: 6001
# highest price: 42000
# strategy: grid
# expected return: 0.47105180802099517
# sharpe ratio: -0.9794238426585673
# *--------------------------------*
# index: 232
# unit: 1
# grid number: 28
# lowest price: 6001
# highest price: 44000
# strategy: grid
# expected return: 0.38611158782560134
# sharpe ratio: -1.118965912365296
# *--------------------------------*
# index: 233
# unit: 1
# grid number: 28
# lowest price: 6001
# highest price: 46000
# strategy: grid
# expected return: 0.3102385076281899
# sharpe ratio: -1.163379603378172
# *--------------------------------*
# index: 234
# unit: 1
# grid number: 28
# lowest price: 6001
# highest price: 48000
# strategy: grid
# expected return: 0.3141230926028818
# sharpe ratio: -1.1251895390997435
# *--------------------------------*
# index: 235
# unit: 1
# grid number: 28
# lowest price: 6001
# highest price: 50000
# strategy: grid
# expected return: 0.20357888441600736
# sharpe ratio: -1.1615498301638982
# *--------------------------------*
# index: 236
# unit: 1
# grid number: 28
# lowest price: 6001
# highest price: 52000
# strategy: grid
# expected return: 0.16477861162630583
# sharpe ratio: -1.2586857426020113
# *--------------------------------*
# index: 237
# unit: 1
# grid number: 28
# lowest price: 6001
# highest price: 54000
# strategy: grid
# expected return: 0.08747918674998094
# sharpe ratio: -1.4178681371384254
# *--------------------------------*
# index: 238
# unit: 1
# grid number: 28
# lowest price: 6001
# highest price: 56000
# strategy: grid
# expected return: -0.004825827657552929
# sharpe ratio: -1.4889670678102156
# *--------------------------------*
# index: 239
# unit: 1
# grid number: 28
# lowest price: 6001
# highest price: 58000
# strategy: grid
# expected return: -0.08912520521636659
# sharpe ratio: -1.4375503962293503
# *--------------------------------*
# index: 240
# unit: 1
# grid number: 28
# lowest price: 8001
# highest price: 40000
# strategy: grid
# expected return: 0.561112731042069
# sharpe ratio: -0.857663441534076
# *--------------------------------*
# index: 241
# unit: 1
# grid number: 28
# lowest price: 8001
# highest price: 42000
# strategy: grid
# expected return: 0.4927865020441137
# sharpe ratio: -0.9285791413891281
# *--------------------------------*
# index: 242
# unit: 1
# grid number: 28
# lowest price: 8001
# highest price: 44000
# strategy: grid
# expected return: 0.41513172197062426
# sharpe ratio: -1.003876435978364
# *--------------------------------*
# index: 243
# unit: 1
# grid number: 28
# lowest price: 8001
# highest price: 46000
# strategy: grid
# expected return: 0.33183605682773415
# sharpe ratio: -1.03857069141099
# *--------------------------------*
# index: 244
# unit: 1
# grid number: 28
# lowest price: 8001
# highest price: 48000
# strategy: grid
# expected return: 0.29555546022475027
# sharpe ratio: -1.0848234889654513
# *--------------------------------*
# index: 245
# unit: 1
# grid number: 28
# lowest price: 8001
# highest price: 50000
# strategy: grid
# expected return: 0.17159509749787388
# sharpe ratio: -1.1708990671723931
# *--------------------------------*
# index: 246
# unit: 1
# grid number: 28
# lowest price: 8001
# highest price: 52000
# strategy: grid
# ...
# *--------------------------------*
# index: 10420
# unit: 10001
# grid number: 36
# lowest price: 4001
# highest price: 40000
# strategy: grid
# expected return: 267.54870650915694
# sharpe ratio: 0.38370576904525766
# *--------------------------------*
# index: 10421
# unit: 10001
# grid number: 36
# lowest price: 4001
# highest price: 42000
# strategy: grid
# expected return: 220.4836539058726
# sharpe ratio: 0.4429477675902665
# *--------------------------------*
# index: 10422
# unit: 10001
# grid number: 36
# lowest price: 4001
# highest price: 44000
# strategy: grid
# expected return: 212.219204504353
# sharpe ratio: 0.45371144999165924
# *--------------------------------*
# index: 10423
# unit: 10001
# grid number: 36
# lowest price: 4001
# highest price: 46000
# strategy: grid
# expected return: 208.4074243448431
# sharpe ratio: 0.42583354555025127
# *--------------------------------*
# index: 10424
# unit: 10001
# grid number: 36
# lowest price: 4001
# highest price: 48000
# strategy: grid
# expected return: 179.03571109465685
# sharpe ratio: 0.3902255392300886
# *--------------------------------*
# index: 10425
# unit: 10001
# grid number: 36
# lowest price: 4001
# highest price: 50000
# strategy: grid
# expected return: 214.40985178247058
# sharpe ratio: 0.43797080155703977
# *--------------------------------*
# index: 10426
# unit: 10001
# grid number: 36
# lowest price: 4001
# highest price: 52000
# strategy: grid
# expected return: 224.42634534147552
# sharpe ratio: 0.4476219863841637
# *--------------------------------*
# index: 10427
# unit: 10001
# grid number: 36
# lowest price: 4001
# highest price: 54000
# strategy: grid
# expected return: 226.06288064530884
# sharpe ratio: 0.44318332850208964
# *--------------------------------*
# index: 10428
# unit: 10001
# grid number: 36
# lowest price: 4001
# highest price: 56000
# strategy: grid
# expected return: 221.11887747089708
# sharpe ratio: 0.40244631194104424
# *--------------------------------*
# index: 10429
# unit: 10001
# grid number: 36
# lowest price: 4001
# highest price: 58000
# strategy: grid
# expected return: 199.60976442172057
# sharpe ratio: 0.3857378756485872
# *--------------------------------*
# index: 10430
# unit: 10001
# grid number: 36
# lowest price: 6001
# highest price: 40000
# strategy: grid
# expected return: 225.92569133951469
# sharpe ratio: 0.41091987148936165
# *--------------------------------*
# index: 10431
# unit: 10001
# grid number: 36
# lowest price: 6001
# highest price: 42000
# strategy: grid
# expected return: 254.04957501529904
# sharpe ratio: 0.36213030181265055
# *--------------------------------*
# index: 10432
# unit: 10001
# grid number: 36
# lowest price: 6001
# highest price: 44000
# strategy: grid
# expected return: 200.88707209069608
# sharpe ratio: 0.40410063037517385
# *--------------------------------*
# index: 10433
# unit: 10001
# grid number: 36
# lowest price: 6001
# highest price: 46000
# strategy: grid
# expected return: 203.92004511257352
# sharpe ratio: 0.4052182173621861
# *--------------------------------*
# index: 10434
# unit: 10001
# grid number: 36
# lowest price: 6001
# highest price: 48000
# strategy: grid
# expected return: 208.0538078102549
# sharpe ratio: 0.37529804191129684
# *--------------------------------*
# index: 10435
# unit: 10001
# grid number: 36
# lowest price: 6001
# highest price: 50000
# strategy: grid
# expected return: 209.38857583253431
# sharpe ratio: 0.38076144389959987
# *--------------------------------*
# index: 10436
# unit: 10001
# grid number: 36
# lowest price: 6001
# highest price: 52000
# strategy: grid
# expected return: 196.7197911885882
# sharpe ratio: 0.3558294873509349
# *--------------------------------*
# index: 10437
# unit: 10001
# grid number: 36
# lowest price: 6001
# highest price: 54000
# strategy: grid
# expected return: 182.7605423640686
# sharpe ratio: 0.3584686750807198
# *--------------------------------*
# index: 10438
# unit: 10001
# grid number: 36
# lowest price: 6001
# highest price: 56000
# strategy: grid
# expected return: 154.21839657213724
# sharpe ratio: 0.36905823403509963
# *--------------------------------*
# index: 10439
# unit: 10001
# grid number: 36
# lowest price: 6001
# highest price: 58000
# strategy: grid
# expected return: 149.39984407879413
# sharpe ratio: 0.35561055033022015
# *--------------------------------*
# index: 10440
# unit: 10001
# grid number: 36
# lowest price: 8001
# highest price: 40000
# strategy: grid
# expected return: 167.30369379454902
# sharpe ratio: 0.4497696475269051
# *--------------------------------*
# index: 10441
# unit: 10001
# grid number: 36
# lowest price: 8001
# highest price: 42000
# strategy: grid
# expected return: 278.90445103869115
# sharpe ratio: 0.3574160921622197
# *--------------------------------*
# index: 10442
# unit: 10001
# grid number: 36
# lowest price: 8001
# highest price: 44000
# strategy: grid
# expected return: 196.3147363734314
# sharpe ratio: 0.3398769606784653
# *--------------------------------*
# index: 10443
# unit: 10001
# grid number: 36
# lowest price: 8001
# highest price: 46000
# strategy: grid
# expected return: 172.91869832709313
# sharpe ratio: 0.4022188510805846
# *--------------------------------*
# index: 10444
# unit: 10001
# grid number: 36
# lowest price: 8001
# highest price: 48000
# strategy: grid
# expected return: 129.12239683094117
# sharpe ratio: 0.4463681571169481
# *--------------------------------*
# index: 10445
# unit: 10001
# grid number: 36
# lowest price: 8001
# highest price: 50000
# strategy: grid
# expected return: 128.42091325822545
# sharpe ratio: 0.44003348715494434
# *--------------------------------*
# index: 10446
# unit: 10001
# grid number: 36
# lowest price: 8001
# highest price: 52000
# strategy: grid
# expected return: 127.86419092489216
# sharpe ratio: 0.43861665410866696
# *--------------------------------*
# index: 10447
# unit: 10001
# grid number: 36
# lowest price: 8001
# highest price: 54000
# strategy: grid
# expected return: 124.4105203962941
# sharpe ratio: 0.4266320635483164
# *--------------------------------*
# index: 10448
# unit: 10001
# grid number: 36
# lowest price: 8001
# highest price: 56000
# strategy: grid
# expected return: 123.95204318060784
# sharpe ratio: 0.4255283809492969
# *--------------------------------*
# index: 10449
# unit: 10001
# grid number: 36
# lowest price: 8001
# highest price: 58000
# strategy: grid
# expected return: 119.94144029767648
# sharpe ratio: 0.405607420509996
# *--------------------------------*
# index: 10450
# unit: 10001
# grid number: 38
# lowest price: 1
# highest price: 40000
# strategy: grid
# expected return: 241.9636683746873
# sharpe ratio: 0.44640171917645105
# *--------------------------------*
# index: 10451
# unit: 10001
# grid number: 38
# lowest price: 1
# highest price: 42000
# strategy: grid
# expected return: 286.4437074353854
# sharpe ratio: 0.47408182368837964
# *--------------------------------*
# index: 10452
# unit: 10001
# grid number: 38
# lowest price: 1
# highest price: 44000
# strategy: grid
# expected return: 214.09246605326317
# sharpe ratio: 0.4332029376856339
# *--------------------------------*
# index: 10453
# unit: 10001
# grid number: 38
# lowest price: 1
# highest price: 46000
# strategy: grid
# expected return: 224.45273655876474
# sharpe ratio: 0.4087042362567162
# *--------------------------------*
# index: 10454
# unit: 10001
# grid number: 38
# lowest price: 1
# highest price: 48000
# strategy: grid
# expected return: 175.70582619415788
# sharpe ratio: 0.3853815458445683
# *--------------------------------*
# index: 10455
# unit: 10001
# grid number: 38
# lowest price: 1
# highest price: 50000
# strategy: grid
# expected return: 227.69159637211294
# sharpe ratio: 0.4537558753191827
# *--------------------------------*
# index: 10456
# unit: 10001
# grid number: 38
# lowest price: 1
# highest price: 52000
# strategy: grid
# expected return: 213.21157431964707
# sharpe ratio: 0.42292006001966187
# *--------------------------------*
# index: 10457
# unit: 10001
# grid number: 38
# lowest price: 1
# highest price: 54000
# strategy: grid
# expected return: 285.8875988734335
# sharpe ratio: 0.4053149653477097
# *--------------------------------*
# index: 10458
# unit: 10001
# grid number: 38
# lowest price: 1
# highest price: 56000
# strategy: grid
# expected return: 185.7650856108483
# sharpe ratio: 0.4159414879133372
# *--------------------------------*
# index: 10459
# unit: 10001
# grid number: 38
# lowest price: 1
# highest price: 58000
# strategy: grid
# expected return: 194.0386653164319
# sharpe ratio: 0.4300632606777663
# *--------------------------------*
# index: 10460
# unit: 10001
# grid number: 38
# lowest price: 2001
# highest price: 40000
# strategy: grid
# expected return: 269.35500108856195
# sharpe ratio: 0.38659379277789674
# *--------------------------------*
# index: 10461
# unit: 10001
# grid number: 38
# lowest price: 2001
# highest price: 42000
# strategy: grid
# expected return: 224.94157167577868
# sharpe ratio: 0.40611309372654114
# *--------------------------------*
# index: 10462
# unit: 10001
# grid number: 38
# lowest price: 2001
# highest price: 44000
# strategy: grid
# expected return: 239.62549205721513
# sharpe ratio: 0.4490821996837278
# *--------------------------------*
# index: 10463
# unit: 10001
# grid number: 38
# lowest price: 2001
# highest price: 46000
# strategy: grid
# expected return: 259.2256647577601
# sharpe ratio: 0.43884526257207324
# *--------------------------------*
# index: 10464
# unit: 10001
# grid number: 38
# lowest price: 2001
# highest price: 48000
# strategy: grid
# expected return: 206.86410993079414
# sharpe ratio: 0.42299142299965237
# *--------------------------------*
# index: 10465
# unit: 10001
# grid number: 38
# lowest price: 2001
# highest price: 50000
# strategy: grid
# expected return: 233.63899089729875
# sharpe ratio: 0.42545333584375644
# *--------------------------------*
# index: 10466
# unit: 10001
# grid number: 38
# lowest price: 2001
# highest price: 52000
# strategy: grid
# expected return: 248.62973325817498
# sharpe ratio: 0.4047419560518349
# *--------------------------------*
# index: 10467
# unit: 10001
# grid number: 38
# lowest price: 2001
# highest price: 54000
# strategy: grid
# expected return: 182.97868212219967
# sharpe ratio: 0.4077389952126281
# *--------------------------------*
# index: 10468
# unit: 10001
# grid number: 38
# lowest price: 2001
# highest price: 56000
# strategy: grid
# expected return: 203.20279563163933
# sharpe ratio: 0.45070525072499623
# *--------------------------------*
# index: 10469
# unit: 10001
# grid number: 38
# lowest price: 2001
# highest price: 58000
# strategy: grid
# expected return: 189.64787981119662
# sharpe ratio: 0.4187294094826607
# *--------------------------------*
# index: 10470
# unit: 10001
# grid number: 38
# lowest price: 4001
# highest price: 40000
# strategy: grid
# expected return: 237.35213776309288
# sharpe ratio: 0.43995225748039807
# *--------------------------------*
# index: 10471
# unit: 10001
# grid number: 38
# lowest price: 4001
# highest price: 42000
# strategy: grid
# expected return: 267.54850657172443
# sharpe ratio: 0.3837055052045696
# *--------------------------------*
# index: 10472
# unit: 10001
# grid number: 38
# lowest price: 4001
# highest price: 44000
# strategy: grid
# expected return: 220.84715136137464
# sharpe ratio: 0.44365520800889374
# *--------------------------------*
# index: 10473
# unit: 10001
# grid number: 38
# lowest price: 4001
# highest price: 46000
# strategy: grid
# expected return: 200.8821295944319
# sharpe ratio: 0.426380390366316
# *--------------------------------*
# index: 10474
# unit: 10001
# grid number: 38
# lowest price: 4001
# highest price: 48000
# strategy: grid
# expected return: 200.81681385298452
# sharpe ratio: 0.3983051258880314
# *--------------------------------*
# index: 10475
# unit: 10001
# grid number: 38
# lowest price: 4001
# highest price: 50000
# strategy: grid
# expected return: 181.85853491744118
# sharpe ratio: 0.3993954799038763
# *--------------------------------*
# index: 10476
# unit: 10001
# grid number: 38
# lowest price: 4001
# highest price: 52000
# strategy: grid
# expected return: 185.98225365675077
# sharpe ratio: 0.4053239376039365
# *--------------------------------*
# index: 10477
# unit: 10001
# grid number: 38
# lowest price: 4001
# highest price: 54000
# strategy: grid
# expected return: 225.95160294744434
# sharpe ratio: 0.45041080825213364
# *--------------------------------*
# index: 10478
# unit: 10001
# grid number: 38
# lowest price: 4001
# highest price: 56000
# strategy: grid
# expected return: 220.8565976464659
# sharpe ratio: 0.43211333953179526
# *--------------------------------*
# index: 10479
# unit: 10001
# grid number: 38
# lowest price: 4001
# highest price: 58000
# strategy: grid
# expected return: 212.8382293882678
# sharpe ratio: 0.4225566854906522
# *--------------------------------*
# index: 10480
# unit: 10001
# grid number: 38
# lowest price: 6001
# highest price: 40000
# strategy: grid
# expected return: 220.4890088788808
# sharpe ratio: 0.41394858798921175
# *--------------------------------*
# index: 10481
# unit: 10001
# grid number: 38
# lowest price: 6001
# highest price: 42000
# strategy: grid
# expected return: 225.64029315084667
# sharpe ratio: 0.41047424820784423
# *--------------------------------*
# index: 10482
# unit: 10001
# grid number: 38
# lowest price: 6001
# highest price: 44000
# strategy: grid
# expected return: 254.04947375388394
# sharpe ratio: 0.3621301751755674
# *--------------------------------*
# index: 10483
# unit: 10001
# grid number: 38
# lowest price: 6001
# highest price: 46000
# strategy: grid
# expected return: 201.04384113548605
# sharpe ratio: 0.4043942688763521
# *--------------------------------*
# index: 10484
# unit: 10001
# grid number: 38
# lowest price: 6001
# highest price: 48000
# strategy: grid
# expected return: 204.249170134788
# sharpe ratio: 0.40584481587892957
# *--------------------------------*
# index: 10485
# unit: 10001
# grid number: 38
# lowest price: 6001
# highest price: 50000
# strategy: grid
# expected return: 211.94387333621827
# sharpe ratio: 0.3825387575555793
# *--------------------------------*
# index: 10486
# unit: 10001
# grid number: 38
# lowest price: 6001
# highest price: 52000
# strategy: grid
# expected return: 213.05629232241174
# sharpe ratio: 0.3850966883048377
# *--------------------------------*
# index: 10487
# unit: 10001
# grid number: 38
# lowest price: 6001
# highest price: 54000
# strategy: grid
# expected return: 197.54703576235917
# sharpe ratio: 0.3572175227891544
# *--------------------------------*
# index: 10488
# unit: 10001
# grid number: 38
# lowest price: 6001
# highest price: 56000
# strategy: grid
# expected return: 190.20606365805577
# sharpe ratio: 0.360012326409607
# *--------------------------------*
# index: 10489
# unit: 10001
# grid number: 38
# lowest price: 6001
# highest price: 58000
# strategy: grid
# expected return: 156.75112147048915
# sharpe ratio: 0.3775378102174521
# *--------------------------------*
# index: 10490
# unit: 10001
# grid number: 38
# lowest price: 8001
# highest price: 40000
# strategy: grid
# expected return: 161.31180318965318
# sharpe ratio: 0.44180903764191726
# *--------------------------------*
# index: 10491
# unit: 10001
# grid number: 38
# lowest price: 8001
# highest price: 42000
# strategy: grid
# expected return: 167.14508308470278
# sharpe ratio: 0.44952382878732394
# *--------------------------------*
# index: 10492
# unit: 10001
# grid number: 38
# lowest price: 8001
# highest price: 44000
# strategy: grid
# expected return: 278.808743489017
# sharpe ratio: 0.3573327473377318
# *--------------------------------*
# index: 10493
# unit: 10001
# grid number: 38
# lowest price: 8001
# highest price: 46000
# strategy: grid
# expected return: 196.31471396665017
# sharpe ratio: 0.3398769362979166
# *--------------------------------*
# index: 10494
# unit: 10001
# grid number: 38
# lowest price: 8001
# highest price: 48000
# strategy: grid
# expected return: 172.95401443058978
# sharpe ratio: 0.4022670676105428
# *--------------------------------*
# index: 10495
# unit: 10001
# grid number: 38
# lowest price: 8001
# highest price: 50000
# strategy: grid
# expected return: 129.16375285467493
# sharpe ratio: 0.44644645117122156
# *--------------------------------*
# index: 10496
# unit: 10001
# grid number: 38
# lowest price: 8001
# highest price: 52000
# strategy: grid
# expected return: 128.50880213395354
# sharpe ratio: 0.4402564386752778
# *--------------------------------*
# index: 10497
# unit: 10001
# grid number: 38
# lowest price: 8001
# highest price: 54000
# strategy: grid
# expected return: 127.98138097605883
# sharpe ratio: 0.43891555361223594
# *--------------------------------*
# index: 10498
# unit: 10001
# grid number: 38
# lowest price: 8001
# highest price: 56000
# strategy: grid
# expected return: 124.53116022996905
# sharpe ratio: 0.42692165284598543
# *--------------------------------*
# index: 10499
# unit: 10001
# grid number: 38
# lowest price: 8001
# highest price: 58000
# strategy: grid
# expected return: 124.09681339405572
# sharpe ratio: 0.4258774194244155

# %%
print(np.argmax(expected), np.argmax(sharpe))
expected_index = np.argmax(expected)
sharpe_index = np.argmax(sharpe)
print(np.max(expected))
print(np.max(sharpe))
# Out:
# 5470 6250
# 4.115399039373435
# 0.6045385478571438

# %%
index = 0
u = 0
for unit in range(1, 10501, 500):
    g = 0
    for grid_number in range(20, 40, 2):
        l = 0
        for lowest_price in range(1, 10000, 2000):
            h = 0
            for highest_price in range(40000, 60000, 2000):
                if (index == expected_index or index == sharpe_index):
                    print(unit, grid_number, lowest_price, highest_price, index)
                    print(u, g, l, h)
                index += 1
                h += 1
            l += 1
        g += 1
    u += 1
# Out:
# 5001 38 4001 40000 5470
# 10 9 2 0
# 6001 30 1 40000 6250
# 12 5 0 0

# %%
grid_parameters = {
    "name":"grid",                                    ## str
    "start_money" : 1000.0,                           ## float    
    "start_storage" : 0.0,                            ## float
    "trading_fee_rate" : 0.002,                       ## float
    "unit" : 0.005,                                   ## float
    "grid_number" : 20,                               ## int  
    "equal_Diff_or_Ratio" : "DIFF",                   ## "DIFF", "RATIO"
    "trading_logistic":"both",                        ## "long", "short", "both"
    "initial_setup":{"type":"None", "portion":0.0},   ## "type": "long", "short" or "None". "portion" : float
    "lowest_price" : 1.0,                             ## float
    "highest_price" : 60000.0                         ## float
}

grid_parameters["unit"] = 6001/100000
grid_parameters["grid_number"] = 30
grid_parameters["lowest_price"] = 1
grid_parameters["highest_price"] = 40000

myGrid = Strategies.Grid(grid_parameters)
sharpe_ratio, expected_return = Strategy_Analysis_Tool.Analysis_tool.Shape_Ratio(myGrid, df, 0.02, window_size=10000, window_off=1000)
print("*--------------------------------*")
print("unit:", myGrid.unit)
print("grid number:", myGrid.grid_number)
print("lowest price:", myGrid.lowest_price)
print("highest price:", myGrid.highest_price)
print("strategy:", myGrid.name)
print("expected return:", expected_return * 100)
print("sharpe ratio:", sharpe_ratio)
# Out:
# *--------------------------------*
# unit: 0.06001
# grid number: 30
# lowest price: 1
# highest price: 40000
# strategy: grid
# expected return: 284.449236306
# sharpe ratio: 0.6045385478571438

# %%
Expected_Return = np.array(expected)
Sharpe_Ratio = np.array(sharpe)
R = Expected_Return.reshape([21, 10, 5, 10])
S = Sharpe_Ratio.reshape([21,10, 5, 10])

# %%
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
 
low = list(range(1, 10000, 2000))
high = list(range(40000, 60000, 2000))
X, Y = np.meshgrid(low, high)

three_dim_R = R[10, 9, :, :]
Z = np.transpose(three_dim_R) * 100
print(np.max(Z))

fig = plt.figure(figsize=(12,10))
ax = plt.axes(projection ='3d')
ax.scatter(40000, 4001, np.max(Z))
ax.set_title('Lowest and highest price with Return')
surf = ax.plot_surface(Y, X, Z, cmap = plt.cm.cividis)
ax.set_xlabel("Highest Price")
ax.set_ylabel("Lowest Price")
ax.set_zlabel("Expected Return (%)")
# Out:
# 411.5399039373435
# Text(0.5, 0, 'Expected Return (%)')

# %%
unit = list(range(1, 10501, 500))
grid_number = list(range(20, 40, 2))
X, Y = np.meshgrid(unit, grid_number)
X = np.array(X) / 100000

three_dim_R = R[:, :, 2, 0]
Z = np.transpose(three_dim_R) * 100
print(np.max(Z))

fig = plt.figure(figsize=(12,10))
ax = plt.axes(projection ='3d')
ax.scatter(38, 0.05001, np.max(Z))
ax.set_title('Grid number and unit with Return')
surf = ax.plot_surface(Y, X, Z, cmap = plt.cm.cividis)
ax.set_xlabel("grid number")
ax.set_ylabel("unit")
ax.set_zlabel("Expected Return (%)")
# Out:
# 411.5399039373435
# Text(0.5, 0, 'Expected Return (%)')

# %%
high = list(range(40000, 60000, 2000))
grid_number = list(range(20, 40, 2))
X, Y = np.meshgrid(high, grid_number)

three_dim_R = R[10, :, 2, :]
# Z = np.transpose(three_dim_R) * 100
Z = three_dim_R * 100
print(np.max(Z))

fig = plt.figure(figsize=(12,10))
ax = plt.axes(projection ='3d')
ax.set_title('Grid number and highest price with Return')
ax.scatter(40000, 38, np.max(Z))
surf = ax.plot_surface(X, Y, Z, cmap = plt.cm.cividis)
ax.set_xlabel("highest price")
ax.set_ylabel("grid number")
ax.set_zlabel("Expected Return (%)")
# Out:
# 411.5399039373435
# Text(0.5, 0, 'Expected Return (%)')

# %%
low = list(range(1, 10000, 2000))
high = list(range(40000, 60000, 2000))
X, Y = np.meshgrid(low, high)

three_dim_R = S[12, 5, :, :]
Z = np.transpose(three_dim_R)
print(np.max(Z))

fig = plt.figure(figsize=(12,10))
ax = plt.axes(projection ='3d')
ax.set_title('Lowest and highest price with Sharpe Ratio')
surf = ax.plot_surface(Y, X, Z, cmap = plt.cm.cividis)
ax.set_xlabel("Highest Price")
ax.set_ylabel("Lowest Price")
ax.scatter(40000, 1, np.max(Z))
ax.set_zlabel("Sharpe Ratio")
# Out:
# 0.6045385478571438
# Text(0.5, 0, 'Sharpe Ratio')

# %%
unit = list(range(1, 10501, 500))
grid_number = list(range(20, 40, 2))
X, Y = np.meshgrid(unit, grid_number)
X = np.array(X) / 100000

three_dim_R = S[:, :, 0, 0]
Z = np.transpose(three_dim_R)
print(np.max(Z))


fig = plt.figure(figsize=(12,10))
ax = plt.axes(projection ='3d')
ax.scatter(30, 0.06001, np.max(Z))
ax.set_title('Grid number and unit with Sharpe Ratio')
surf = ax.plot_surface(Y, X, Z, cmap = plt.cm.cividis)
ax.set_xlabel("grid number")
ax.set_ylabel("unit")
ax.set_zlabel("Sharpe Ratio")
# Out:
# 0.6045385478571438
# Text(0.5, 0, 'Sharpe Ratio')

# %%
high = list(range(40000, 60000, 2000))
grid_number = list(range(20, 40, 2))
X, Y = np.meshgrid(high, grid_number)

three_dim_R = S[12, :, 0, :]
# Z = np.transpose(three_dim_R)
Z = three_dim_R
print(np.max(Z))

fig = plt.figure(figsize=(12,10))
ax = plt.axes(projection ='3d')
ax.set_title('Grid number and highest price with Sharpe Ratio')
surf = ax.plot_surface(Y, X, Z, cmap = plt.cm.cividis)
ax.scatter(30, 40000, np.max(Z))
ax.set_xlabel("grid number")
ax.set_ylabel("highest price")
ax.set_zlabel("Sharpe Ratio")
# Out:
# 0.6045385478571438
# Text(0.5, 0, 'Sharpe Ratio')
