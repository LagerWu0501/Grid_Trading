# %%
import numpy as np
import pandas as pd
import Strategies 
import Strategy_Analysis_Tool 
from binance.client import Client
from matplotlib import pyplot as plt

# %%
# Get data
symbol = "BTCUSDT"
timeFrame = "1h"
startDate = "2017-01-01"
endDate = "2022-08-28"
client = Client()
bars = client.get_historical_klines(symbol=symbol,interval=timeFrame,start_str=startDate, end_str = endDate)
df = pd.DataFrame(bars[:],columns=["timestamp","open","high","low","close","volume", "close_time", "quote_asset_volume", "number_of_trade", "TBB", "TBQ", "ignore"])
df["date"]=pd.to_datetime(df["timestamp"],unit="ms").astype(str)
df = df.drop(["timestamp", "close_time", "quote_asset_volume", "number_of_trade", "TBB", "TBQ", "ignore"], axis=1)
df["open"] = pd.to_numeric(df["open"])
df["high"] = pd.to_numeric(df["high"])
df["low"] = pd.to_numeric(df["low"])
df["close"] = pd.to_numeric(df["close"])
df["volume"] = pd.to_numeric(df["volume"])
df
# Out:
#            open      high       low     close       volume  \
# 0       4261.48   4313.62   4261.32   4308.83    47.181009
# 1       4308.83   4328.69   4291.37   4315.32    23.234916
# 2       4330.29   4345.45   4309.37   4324.35     7.229691
# 3       4316.62   4349.99   4287.41   4349.99     4.443249
# 4       4333.32   4377.85   4333.32   4360.69     0.972807
# ...         ...       ...       ...       ...          ...
# 43953  20018.00  20040.40  19941.83  20007.99  4374.049180
# 43954  20007.99  20029.84  19870.01  19873.06  2779.324280
# 43955  19874.25  20103.57  19858.43  20020.08  8501.926530
# 43956  20021.35  20087.65  19992.55  20037.60  5025.547650
# 43957  20037.60  20051.22  19926.78  19992.16  5346.543810
#
#                       date
# 0      2017-08-17 04:00:00
# 1      2017-08-17 05:00:00
# 2      2017-08-17 06:00:00
# 3      2017-08-17 07:00:00
# 4      2017-08-17 08:00:00
# ...                    ...
# 43953  2022-08-27 20:00:00
# 43954  2022-08-27 21:00:00
# 43955  2022-08-27 22:00:00
# 43956  2022-08-27 23:00:00
# 43957  2022-08-28 00:00:00
#
# [43958 rows x 6 columns]

# %%
# Grid strategy
grid_parameters = {
    "name":"grid",                                    ## str
    "start_money" : 1000.0,                           ## float    
    "start_storage" : 0.0,                            ## float
    "trading_fee_rate" : 0.002,                       ## float
    "unit" : 0.005,                                   ## float
    "grid_number" : 20,                               ## int  
    "equal_Diff_or_Ratio" : "RATIO",                  ## "DIFF", "RATIO"
    "trading_logistic":"both",                        ## "long", "short", "both"
    "initial_setup":{"type":"None", "portion":0.0},   ## "type": "long", "short" or "None". "portion" : float
    "lowest_price" : 1.0,                             ## float
    "highest_price" : 60000.0                         ## float
}
myGrid = Strategies.Grid(grid_parameters)
# Buy and hold
buy_and_hold_parameters = {
    "name":"buy and hold",                            ## str
    "start_money" : 1000.0,                           ## float    
    "start_storage" : 0.0,                            ## float
    "trading_fee_rate" : 0.002,                       ## float
    "unit" : 0.0001,                                  ## float
}
buy_and_hodl = Strategies.Buy_and_Hold(buy_and_hold_parameters)

# %%
sharpe_ratio, expected_return = Strategy_Analysis_Tool.Analysis_tool.Shape_Ratio(myGrid, df, 0.02, window_size=10000, window_off=1000)
print("*--------------------------------*")
print("strategy:", myGrid.name)
print("expected return:", expected_return * 100)
print("sharpe ratio:", sharpe_ratio)
sharpe_ratio, expected_return = Strategy_Analysis_Tool.Analysis_tool.Shape_Ratio(buy_and_hodl, df, 0.02, window_size=10000, window_off=1000)
print("*--------------------------------*")
print("strategy:", buy_and_hodl.name)
print("expected return:", expected_return * 100)
print("sharpe ratio:", sharpe_ratio)

profit, trading_count, buy_record, sell_record, MDD = myGrid.back_test(df)
print("*--------------------------------*")
print("strategy:", myGrid.name)
print("trading count:", trading_count)
print("profit:", profit * 100)
print("MDD:", MDD)
profit, trading_count, buy_record, sell_record, MDD = buy_and_hodl.back_test(df)
print("*--------------------------------*")
print("strategy:", buy_and_hodl.name)
print("trading count:", trading_count)
print("profit:", profit * 100)
print("MDD:", MDD)
# Out:
# *--------------------------------*
# strategy: grid
# expected return: 7.761034560884977
# sharpe ratio: 0.22050978590443993
# *--------------------------------*
# strategy: buy and hold
# expected return: 121.7750752080959
# sharpe ratio: 0.6863524542570872
# *--------------------------------*
# strategy: grid
# trading count: 18
# profit: 4.204703949015425
# MDD: 0.39898075507949926
# *--------------------------------*
# strategy: buy and hold
# trading count: 2
# profit: 369.1365441114355
# MDD: 0.957469866475196

# %% [markdown]
# ## Brute Force and find the best parameters

# %%
# Buy and hold
buy_and_hold_parameters = {
    "name":"buy and hold",                            ## str
    "start_money" : 1000.0,                           ## float    
    "start_storage" : 0.0,                            ## float
    "trading_fee_rate" : 0.002,                       ## float
    "unit" : 0.0001,                                  ## float
}
buy_and_hodl = Strategies.Buy_and_Hold(buy_and_hold_parameters)
sharpe_ratio, expected_return = Strategy_Analysis_Tool.Analysis_tool.Shape_Ratio(buy_and_hodl, df, 0.02, window_size=10000, window_off=1000)
print("*--------------------------------*")
print("strategy:", buy_and_hodl.name)
print("expected return:", expected_return * 100)
print("sharpe ratio:", sharpe_ratio)
# Out:
# *--------------------------------*
# strategy: buy and hold
# expected return: 121.7750752080959
# sharpe ratio: 0.6863524542570872

# %%
grid_parameters = {
    "name":"grid",                                    ## str
    "start_money" : 1000.0,                           ## float    
    "start_storage" : 0.0,                            ## float
    "trading_fee_rate" : 0.002,                       ## float
    "unit" : 0.005,                                   ## float
    "grid_number" : 20,                               ## int  
    "equal_Diff_or_Ratio" : "RATIO",                  ## "DIFF", "RATIO"
    "trading_logistic":"both",                        ## "long", "short", "both"
    "initial_setup":{"type":"None", "portion":0.0},   ## "type": "long", "short" or "None". "portion" : float
    "lowest_price" : 1.0,                             ## float
    "highest_price" : 60000.0                         ## float
}

index = 0
sharpe = []
expected = []
for unit in range(1, 10501, 500):
    for grid_number in range(20, 40, 2):
        for lowest_price in range(1, 10000, 2000):
            for highest_price in range(40000, 60000, 2000):
                grid_parameters["unit"] = unit/100000
                grid_parameters["grid_number"] = grid_number
                grid_parameters["lowest_price"] = lowest_price
                grid_parameters["highest_price"] = highest_price

                myGrid = Strategies.Grid(grid_parameters)
                sharpe_ratio, expected_return = Strategy_Analysis_Tool.Analysis_tool.Shape_Ratio(myGrid, df, 0.02, window_size=10000, window_off=1000)
                print("*--------------------------------*")
                print("index:", index)
                print("unit:", unit)
                print("grid number:", grid_number)
                print("lowest price:", lowest_price)
                print("highest price:", highest_price)
                print("strategy:", myGrid.name)
                print("expected return:", expected_return * 100)
                print("sharpe ratio:", sharpe_ratio)
                sharpe.append(sharpe_ratio)
                expected.append(expected_return)
                index += 1
# Out:
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 1
# highest price: 40000
# strategy: buy and hold
# expected return: 0.027807714000345766
# sharpe ratio: -32.65642911910087
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 1
# highest price: 42000
# strategy: buy and hold
# expected return: 0.027488246827290907
# sharpe ratio: -33.38327645440181
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 1
# highest price: 44000
# strategy: buy and hold
# expected return: 0.026283789674093158
# sharpe ratio: -33.93899136609739
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 1
# highest price: 46000
# strategy: buy and hold
# expected return: 0.02544836088902216
# sharpe ratio: -34.039274282786465
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 1
# highest price: 48000
# strategy: buy and hold
# expected return: 0.025137501677098124
# sharpe ratio: -34.908428094599984
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 1
# highest price: 50000
# strategy: buy and hold
# expected return: 0.02313853328497176
# sharpe ratio: -35.469558470565076
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 1
# highest price: 52000
# strategy: buy and hold
# expected return: 0.022435958772078216
# sharpe ratio: -36.42971411417252
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 1
# highest price: 54000
# strategy: buy and hold
# expected return: 0.01919945717929783
# sharpe ratio: -35.89877654905963
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 1
# highest price: 56000
# strategy: buy and hold
# expected return: 0.017305381769208386
# sharpe ratio: -36.60392211928871
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 1
# highest price: 58000
# strategy: buy and hold
# expected return: 0.01500601748310962
# sharpe ratio: -37.30110215925314
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 2001
# highest price: 40000
# strategy: buy and hold
# expected return: 0.15865386623812952
# sharpe ratio: -5.154243122816915
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 2001
# highest price: 42000
# strategy: buy and hold
# expected return: 0.12287226013857513
# sharpe ratio: -5.954808504499207
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 2001
# highest price: 44000
# strategy: buy and hold
# expected return: 0.11885466233772625
# sharpe ratio: -6.181131833553167
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 2001
# highest price: 46000
# strategy: buy and hold
# expected return: 0.1061825441994091
# sharpe ratio: -6.790710967143314
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 2001
# highest price: 48000
# strategy: buy and hold
# expected return: 0.11358609863775118
# sharpe ratio: -6.194459764278834
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 2001
# highest price: 50000
# strategy: buy and hold
# expected return: 0.12642727877442927
# sharpe ratio: -5.8024697686816396
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 2001
# highest price: 52000
# strategy: buy and hold
# expected return: 0.10870837061735233
# sharpe ratio: -5.858591764663451
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 2001
# highest price: 54000
# strategy: buy and hold
# expected return: 0.11357466545440169
# sharpe ratio: -5.986498677915827
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 2001
# highest price: 56000
# strategy: buy and hold
# expected return: 0.0841586731729204
# sharpe ratio: -7.067770324844912
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 2001
# highest price: 58000
# strategy: buy and hold
# expected return: 0.08146521841307537
# sharpe ratio: -6.532428612140416
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 4001
# highest price: 40000
# strategy: buy and hold
# expected return: 0.18850330163560228
# sharpe ratio: -3.8734382095695428
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 4001
# highest price: 42000
# strategy: buy and hold
# expected return: 0.17667434055629133
# sharpe ratio: -4.045768150513924
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 4001
# highest price: 44000
# strategy: buy and hold
# expected return: 0.19046263440913114
# sharpe ratio: -3.779847000483305
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 4001
# highest price: 46000
# strategy: buy and hold
# expected return: 0.173093868146703
# sharpe ratio: -3.8112625241674936
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 4001
# highest price: 48000
# strategy: buy and hold
# expected return: 0.17322634867766606
# sharpe ratio: -3.890983799959387
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 4001
# highest price: 50000
# strategy: buy and hold
# expected return: 0.1714722358259053
# sharpe ratio: -3.7817650770690077
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 4001
# highest price: 52000
# strategy: buy and hold
# expected return: 0.1437392706021974
# sharpe ratio: -4.100868723695864
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 4001
# highest price: 54000
# strategy: buy and hold
# expected return: 0.16316660086652432
# sharpe ratio: -3.8675833036401936
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 4001
# highest price: 56000
# strategy: buy and hold
# expected return: 0.13821765357687388
# sharpe ratio: -4.271762714660683
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 4001
# highest price: 58000
# strategy: buy and hold
# expected return: 0.13833227328174053
# sharpe ratio: -4.10952313824097
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 6001
# highest price: 40000
# strategy: buy and hold
# expected return: 0.2313740150999322
# sharpe ratio: -2.78106356961083
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 6001
# highest price: 42000
# strategy: buy and hold
# expected return: 0.20668956009712058
# sharpe ratio: -3.1288111492185755
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 6001
# highest price: 44000
# strategy: buy and hold
# expected return: 0.2222118579164938
# sharpe ratio: -2.8668090203197556
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 6001
# highest price: 46000
# strategy: buy and hold
# expected return: 0.2325998488393663
# sharpe ratio: -2.8258946519545813
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 6001
# highest price: 48000
# strategy: buy and hold
# expected return: 0.1845742341631264
# sharpe ratio: -3.2936563825623546
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 6001
# highest price: 50000
# strategy: buy and hold
# expected return: 0.19982100725771512
# sharpe ratio: -3.163641086968881
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 6001
# highest price: 52000
# strategy: buy and hold
# expected return: 0.1722233844008783
# sharpe ratio: -3.266809950796546
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 6001
# highest price: 54000
# strategy: buy and hold
# expected return: 0.12805998153092346
# sharpe ratio: -3.726641915139789
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 6001
# highest price: 56000
# strategy: buy and hold
# expected return: 0.1171682617833924
# sharpe ratio: -3.892947934834004
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 6001
# highest price: 58000
# strategy: buy and hold
# expected return: 0.1222485036853641
# sharpe ratio: -3.6722664797700646
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 8001
# highest price: 40000
# strategy: buy and hold
# expected return: 0.21249662073261377
# sharpe ratio: -2.740612076640603
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 8001
# highest price: 42000
# strategy: buy and hold
# expected return: 0.1993425470744964
# sharpe ratio: -2.816193238892097
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 8001
# highest price: 44000
# strategy: buy and hold
# expected return: 0.18295887129643437
# sharpe ratio: -2.9975198242004306
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 8001
# highest price: 46000
# strategy: buy and hold
# expected return: 0.18215831196803262
# sharpe ratio: -2.866703720294732
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 8001
# highest price: 48000
# strategy: buy and hold
# expected return: 0.16012072207715008
# sharpe ratio: -3.1774589755017186
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 8001
# highest price: 50000
# strategy: buy and hold
# expected return: 0.12817385113511262
# sharpe ratio: -3.366037199972561
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 8001
# highest price: 52000
# strategy: buy and hold
# expected return: 0.1503352130020523
# sharpe ratio: -3.0376768179703113
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 8001
# highest price: 54000
# strategy: buy and hold
# expected return: 0.12988159584697445
# sharpe ratio: -3.2401247237437185
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 8001
# highest price: 56000
# strategy: buy and hold
# expected return: 0.11064342283999623
# sharpe ratio: -3.3912634516265965
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 20
# lowest price: 8001
# highest price: 58000
# strategy: buy and hold
# expected return: 0.07838637494348995
# sharpe ratio: -3.7008652283398353
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 1
# highest price: 40000
# strategy: buy and hold
# expected return: 0.0294874491923535
# sharpe ratio: -33.2289280722902
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 1
# highest price: 42000
# strategy: buy and hold
# expected return: 0.026601586739815275
# sharpe ratio: -33.21947114045961
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 1
# highest price: 44000
# strategy: buy and hold
# expected return: 0.02561591953738986
# sharpe ratio: -34.770376702779835
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 1
# highest price: 46000
# strategy: buy and hold
# expected return: 0.02175594188600485
# sharpe ratio: -37.721890999975855
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 1
# highest price: 48000
# strategy: buy and hold
# expected return: 0.0331486187829756
# sharpe ratio: -26.133004551998543
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 1
# highest price: 50000
# strategy: buy and hold
# expected return: 0.030897706275459985
# sharpe ratio: -26.592437012463428
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 1
# highest price: 52000
# strategy: buy and hold
# expected return: 0.029257189042684716
# sharpe ratio: -27.335176757328288
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 1
# highest price: 54000
# strategy: buy and hold
# expected return: 0.028699611750453324
# sharpe ratio: -28.128417152827137
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 1
# highest price: 56000
# strategy: buy and hold
# expected return: 0.026332924417112526
# sharpe ratio: -28.593939321531725
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 1
# highest price: 58000
# strategy: buy and hold
# expected return: 0.023410431328982687
# sharpe ratio: -28.911468927252784
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 2001
# highest price: 40000
# strategy: buy and hold
# expected return: 0.1828670131952793
# sharpe ratio: -4.600822237796228
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 2001
# highest price: 42000
# strategy: buy and hold
# expected return: 0.13576331876957665
# sharpe ratio: -5.473038867230547
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 2001
# highest price: 44000
# strategy: buy and hold
# expected return: 0.12383359363808126
# sharpe ratio: -5.561128389505017
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 2001
# highest price: 46000
# strategy: buy and hold
# expected return: 0.13000700029693046
# sharpe ratio: -5.2715685906124
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 2001
# highest price: 48000
# strategy: buy and hold
# expected return: 0.12183853477399176
# sharpe ratio: -5.732045247547878
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 2001
# highest price: 50000
# strategy: buy and hold
# expected return: 0.14318528585058898
# sharpe ratio: -4.90017093422651
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 2001
# highest price: 52000
# strategy: buy and hold
# expected return: 0.1271207563011775
# sharpe ratio: -5.282006902526907
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 2001
# highest price: 54000
# strategy: buy and hold
# expected return: 0.14214666327084224
# sharpe ratio: -4.9075013363128965
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 2001
# highest price: 56000
# strategy: buy and hold
# expected return: 0.11989312662172272
# sharpe ratio: -5.024312067712618
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 2001
# highest price: 58000
# strategy: buy and hold
# expected return: 0.08517514508970908
# sharpe ratio: -5.741426938604918
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 4001
# highest price: 40000
# strategy: buy and hold
# expected return: 0.23575236762443208
# sharpe ratio: -3.07065773473883
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 4001
# highest price: 42000
# strategy: buy and hold
# expected return: 0.2256761663322436
# sharpe ratio: -3.054602915655565
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 4001
# highest price: 44000
# strategy: buy and hold
# expected return: 0.20591050378942324
# sharpe ratio: -3.3068088823299977
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 4001
# highest price: 46000
# strategy: buy and hold
# expected return: 0.22258636203508247
# sharpe ratio: -3.065598299269069
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 4001
# highest price: 48000
# strategy: buy and hold
# expected return: 0.20575781194382864
# sharpe ratio: -3.2452176030762403
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 4001
# highest price: 50000
# strategy: buy and hold
# expected return: 0.16356039718907228
# sharpe ratio: -3.7649874521768227
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 4001
# highest price: 52000
# strategy: buy and hold
# expected return: 0.16271136641930856
# sharpe ratio: -3.6778601605289976
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 4001
# highest price: 54000
# strategy: buy and hold
# expected return: 0.1811738815419734
# sharpe ratio: -3.451406469548463
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 4001
# highest price: 56000
# strategy: buy and hold
# expected return: 0.1582907547508298
# sharpe ratio: -3.5916150738950936
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 4001
# highest price: 58000
# strategy: buy and hold
# expected return: 0.12630732659726573
# sharpe ratio: -3.8050792886065357
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 6001
# highest price: 40000
# strategy: buy and hold
# expected return: 0.24715972095048344
# sharpe ratio: -2.6334534330936195
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 6001
# highest price: 42000
# strategy: buy and hold
# expected return: 0.2071691682348099
# sharpe ratio: -2.891650505395907
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 6001
# highest price: 44000
# strategy: buy and hold
# expected return: 0.22113568232077102
# sharpe ratio: -2.6952489870542404
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 6001
# highest price: 46000
# strategy: buy and hold
# expected return: 0.20924102298947972
# sharpe ratio: -2.8341987183505264
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 6001
# highest price: 48000
# strategy: buy and hold
# expected return: 0.22458212384634268
# sharpe ratio: -2.603239439487434
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 6001
# highest price: 50000
# strategy: buy and hold
# expected return: 0.21486844692852688
# sharpe ratio: -2.754247217140063
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 6001
# highest price: 52000
# strategy: buy and hold
# expected return: 0.1770668921385961
# sharpe ratio: -2.9724108099242734
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 6001
# highest price: 54000
# strategy: buy and hold
# expected return: 0.19438302182401263
# sharpe ratio: -2.7731091530954712
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 6001
# highest price: 56000
# strategy: buy and hold
# expected return: 0.19479603512117274
# sharpe ratio: -2.712855730865006
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 6001
# highest price: 58000
# strategy: buy and hold
# expected return: 0.1429426551210741
# sharpe ratio: -3.1385792221532327
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 8001
# highest price: 40000
# strategy: buy and hold
# expected return: 0.26924593086802967
# sharpe ratio: -2.1397947077686927
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 8001
# highest price: 42000
# strategy: buy and hold
# expected return: 0.2061250741505583
# sharpe ratio: -2.4801499618581997
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 8001
# highest price: 44000
# strategy: buy and hold
# expected return: 0.20796127807993936
# sharpe ratio: -2.563531966777896
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 8001
# highest price: 46000
# strategy: buy and hold
# expected return: 0.2116329792306036
# sharpe ratio: -2.4262320958045196
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 8001
# highest price: 48000
# strategy: buy and hold
# expected return: 0.16745340924187527
# sharpe ratio: -2.73732445152683
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 8001
# highest price: 50000
# strategy: buy and hold
# expected return: 0.1839237221982604
# sharpe ratio: -2.5376145953975278
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 8001
# highest price: 52000
# strategy: buy and hold
# expected return: 0.14868099539070578
# sharpe ratio: -2.8061772991416047
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 8001
# highest price: 54000
# strategy: buy and hold
# expected return: 0.13404533207938799
# sharpe ratio: -2.985200747521233
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 8001
# highest price: 56000
# strategy: buy and hold
# expected return: 0.13145004088861972
# sharpe ratio: -2.7319767858952324
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 22
# lowest price: 8001
# highest price: 58000
# strategy: buy and hold
# expected return: 0.1011714881105791
# sharpe ratio: -3.1004642480718383
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 1
# highest price: 40000
# strategy: buy and hold
# expected return: 0.035211388145668654
# sharpe ratio: -26.473643704416443
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 1
# highest price: 42000
# strategy: buy and hold
# expected return: 0.033077530871295
# sharpe ratio: -26.785298898445582
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 1
# highest price: 44000
# strategy: buy and hold
# expected return: 0.031130770802894517
# sharpe ratio: -27.319163758287004
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 1
# highest price: 46000
# strategy: buy and hold
# expected return: 0.033297772575748334
# sharpe ratio: -26.45828008383871
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 1
# highest price: 48000
# strategy: buy and hold
# expected return: 0.03209157924901748
# sharpe ratio: -27.104297414886513
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 1
# highest price: 50000
# strategy: buy and hold
# expected return: 0.030940948268402185
# sharpe ratio: -28.10009968185267
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 1
# highest price: 52000
# strategy: buy and hold
# expected return: 0.02907601873361346
# sharpe ratio: -28.235740184125646
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 1
# highest price: 54000
# strategy: buy and hold
# expected return: 0.02727378751087866
# sharpe ratio: -28.712535047219387
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 1
# highest price: 56000
# strategy: buy and hold
# expected return: 0.026931928891684716
# sharpe ratio: -28.91584832730118
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 1
# highest price: 58000
# strategy: buy and hold
# expected return: 0.024031908759950642
# sharpe ratio: -29.299110580296677
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 2001
# highest price: 40000
# strategy: buy and hold
# expected return: 0.1818892793578711
# sharpe ratio: -4.133075472933893
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 2001
# highest price: 42000
# strategy: buy and hold
# expected return: 0.17055866865233177
# sharpe ratio: -4.640102315979605
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 2001
# highest price: 44000
# strategy: buy and hold
# expected return: 0.1681057002519919
# sharpe ratio: -4.327872492010885
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 2001
# highest price: 46000
# strategy: buy and hold
# expected return: 0.14388486860142627
# sharpe ratio: -4.754886685915469
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 2001
# highest price: 48000
# strategy: buy and hold
# expected return: 0.162947986445733
# sharpe ratio: -4.297891562540985
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 2001
# highest price: 50000
# strategy: buy and hold
# expected return: 0.17621037568449888
# sharpe ratio: -4.0557292934602955
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 2001
# highest price: 52000
# strategy: buy and hold
# expected return: 0.16680114823548173
# sharpe ratio: -4.3117683977048085
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 2001
# highest price: 54000
# strategy: buy and hold
# expected return: 0.12854577065788117
# sharpe ratio: -4.9996847928148265
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 2001
# highest price: 56000
# strategy: buy and hold
# expected return: 0.10501686256086519
# sharpe ratio: -5.1510166516011076
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 2001
# highest price: 58000
# strategy: buy and hold
# expected return: 0.10309283641584958
# sharpe ratio: -4.8726512470296655
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 4001
# highest price: 40000
# strategy: buy and hold
# expected return: 0.2633631447191065
# sharpe ratio: -2.587976675595919
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 4001
# highest price: 42000
# strategy: buy and hold
# expected return: 0.24314234565603934
# sharpe ratio: -2.737578693682929
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 4001
# highest price: 44000
# strategy: buy and hold
# expected return: 0.25024737779815265
# sharpe ratio: -2.668663416256725
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 4001
# highest price: 46000
# strategy: buy and hold
# expected return: 0.2809514753321965
# sharpe ratio: -2.4654102648242913
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 4001
# highest price: 48000
# strategy: buy and hold
# expected return: 0.2187266101874674
# sharpe ratio: -2.943440239189954
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 4001
# highest price: 50000
# strategy: buy and hold
# expected return: 0.21289733223876878
# sharpe ratio: -2.9455878249782708
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 4001
# highest price: 52000
# strategy: buy and hold
# expected return: 0.2011200969662194
# sharpe ratio: -2.93158603636371
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 4001
# highest price: 54000
# strategy: buy and hold
# expected return: 0.1629195499864372
# sharpe ratio: -3.394101412876987
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 4001
# highest price: 56000
# strategy: buy and hold
# expected return: 0.1760261154800687
# sharpe ratio: -3.165732309042733
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 4001
# highest price: 58000
# strategy: buy and hold
# expected return: 0.18229541506037508
# sharpe ratio: -2.8725355830156944
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 6001
# highest price: 40000
# strategy: buy and hold
# expected return: 0.259969500781153
# sharpe ratio: -2.330502688987729
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 6001
# highest price: 42000
# strategy: buy and hold
# expected return: 0.2753132316487615
# sharpe ratio: -2.1552754382302073
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 6001
# highest price: 44000
# strategy: buy and hold
# expected return: 0.2600688907725324
# sharpe ratio: -2.2702542530234187
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 6001
# highest price: 46000
# strategy: buy and hold
# expected return: 0.26561614228696323
# sharpe ratio: -2.233021905734241
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 6001
# highest price: 48000
# strategy: buy and hold
# expected return: 0.22818372281520383
# sharpe ratio: -2.480023978624262
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 6001
# highest price: 50000
# strategy: buy and hold
# expected return: 0.19532231774941175
# sharpe ratio: -2.6163602230173426
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 6001
# highest price: 52000
# strategy: buy and hold
# expected return: 0.22100269518401006
# sharpe ratio: -2.347510595325118
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 6001
# highest price: 54000
# strategy: buy and hold
# expected return: 0.1906300678558623
# sharpe ratio: -2.687935213424924
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 6001
# highest price: 56000
# strategy: buy and hold
# expected return: 0.13994992379955185
# sharpe ratio: -2.808181618669105
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 6001
# highest price: 58000
# strategy: buy and hold
# expected return: 0.17360706493222905
# sharpe ratio: -2.5670305282842443
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 8001
# highest price: 40000
# strategy: buy and hold
# expected return: 0.31847370459773655
# sharpe ratio: -1.7717530544946463
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 8001
# highest price: 42000
# strategy: buy and hold
# expected return: 0.2833927180424957
# sharpe ratio: -1.8910728655777203
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 8001
# highest price: 44000
# strategy: buy and hold
# expected return: 0.2488755697088215
# sharpe ratio: -2.071731303368032
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 8001
# highest price: 46000
# strategy: buy and hold
# expected return: 0.27806113744692745
# sharpe ratio: -1.957002099242749
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 8001
# highest price: 48000
# strategy: buy and hold
# expected return: 0.22648406948783803
# sharpe ratio: -2.053893559925122
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 8001
# highest price: 50000
# strategy: buy and hold
# expected return: 0.17939426120890203
# sharpe ratio: -2.4652574418128004
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 8001
# highest price: 52000
# strategy: buy and hold
# expected return: 0.17972634076796593
# sharpe ratio: -2.3151623152883327
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 8001
# highest price: 54000
# strategy: buy and hold
# expected return: 0.1768546770165261
# sharpe ratio: -2.3823516971650847
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 8001
# highest price: 56000
# strategy: buy and hold
# expected return: 0.12341827328374863
# sharpe ratio: -2.4777592237235426
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 24
# lowest price: 8001
# highest price: 58000
# strategy: buy and hold
# expected return: 0.13726165217974035
# sharpe ratio: -2.526206216735644
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 1
# highest price: 40000
# strategy: buy and hold
# expected return: 0.03498995476714246
# sharpe ratio: -27.41802526502015
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 1
# highest price: 42000
# strategy: buy and hold
# expected return: 0.03343724361343113
# sharpe ratio: -27.85208474568398
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 1
# highest price: 44000
# strategy: buy and hold
# expected return: 0.030657674860392555
# sharpe ratio: -28.245421228559742
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 1
# highest price: 46000
# strategy: buy and hold
# expected return: 0.03441077726321049
# sharpe ratio: -27.191482693238054
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 1
# highest price: 48000
# strategy: buy and hold
# expected return: 0.03247195697074503
# sharpe ratio: -27.32039671818297
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 1
# highest price: 50000
# strategy: buy and hold
# expected return: 0.02999351755756065
# sharpe ratio: -27.75827882553443
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 1
# highest price: 52000
# strategy: buy and hold
# expected return: 0.037068109327002635
# sharpe ratio: -21.83143823869341
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 1
# highest price: 54000
# strategy: buy and hold
# expected return: 0.036427984072757366
# sharpe ratio: -23.033089521301644
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 1
# highest price: 56000
# strategy: buy and hold
# expected return: 0.03485863565125856
# sharpe ratio: -22.5551847586041
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 1
# highest price: 58000
# strategy: buy and hold
# expected return: 0.027864837585207497
# sharpe ratio: -24.178087424824884
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 2001
# highest price: 40000
# strategy: buy and hold
# expected return: 0.1991176202197009
# sharpe ratio: -3.8924038303294957
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 2001
# highest price: 42000
# strategy: buy and hold
# expected return: 0.18764344652084167
# sharpe ratio: -3.897346010340549
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 2001
# highest price: 44000
# strategy: buy and hold
# expected return: 0.20918301782327425
# sharpe ratio: -3.4741282772534
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 2001
# highest price: 46000
# strategy: buy and hold
# expected return: 0.18289230118905517
# sharpe ratio: -3.819283490637842
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 2001
# highest price: 48000
# strategy: buy and hold
# expected return: 0.1830660409030085
# sharpe ratio: -3.8053329431202014
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 2001
# highest price: 50000
# strategy: buy and hold
# expected return: 0.17676760430449937
# sharpe ratio: -3.796072123457349
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 2001
# highest price: 52000
# strategy: buy and hold
# expected return: 0.16299102832610332
# sharpe ratio: -3.962770680991424
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 2001
# highest price: 54000
# strategy: buy and hold
# expected return: 0.1515407103497948
# sharpe ratio: -4.399643087238453
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 2001
# highest price: 56000
# strategy: buy and hold
# expected return: 0.13165212229000642
# sharpe ratio: -4.286232963250152
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 2001
# highest price: 58000
# strategy: buy and hold
# expected return: 0.1234891841317733
# sharpe ratio: -4.1465664350801985
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 4001
# highest price: 40000
# strategy: buy and hold
# expected return: 0.30803873263018017
# sharpe ratio: -2.207722029757593
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 4001
# highest price: 42000
# strategy: buy and hold
# expected return: 0.2639741095202891
# sharpe ratio: -2.4968354800458914
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 4001
# highest price: 44000
# strategy: buy and hold
# expected return: 0.2867423900800903
# sharpe ratio: -2.3399525493919158
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 4001
# highest price: 46000
# strategy: buy and hold
# expected return: 0.2302968881176709
# sharpe ratio: -2.656636884166388
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 4001
# highest price: 48000
# strategy: buy and hold
# expected return: 0.2621027303075132
# sharpe ratio: -2.436786602623712
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 4001
# highest price: 50000
# strategy: buy and hold
# expected return: 0.2510361203336094
# sharpe ratio: -2.407959574688471
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 4001
# highest price: 52000
# strategy: buy and hold
# expected return: 0.20524331937486676
# sharpe ratio: -2.798726173280837
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 4001
# highest price: 54000
# strategy: buy and hold
# expected return: 0.23493307103884445
# sharpe ratio: -2.4993043187118174
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 4001
# highest price: 56000
# strategy: buy and hold
# expected return: 0.24181024214302455
# sharpe ratio: -2.3824659452803005
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 4001
# highest price: 58000
# strategy: buy and hold
# expected return: 0.18951359842487486
# sharpe ratio: -2.72067023078706
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 6001
# highest price: 40000
# strategy: buy and hold
# expected return: 0.3381949430625686
# sharpe ratio: -1.8250562673004163
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 6001
# highest price: 42000
# strategy: buy and hold
# expected return: 0.27245657529803613
# sharpe ratio: -2.0937435813558753
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 6001
# highest price: 44000
# strategy: buy and hold
# expected return: 0.2857735180372568
# sharpe ratio: -1.978720916743739
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 6001
# highest price: 46000
# strategy: buy and hold
# expected return: 0.27215017085647747
# sharpe ratio: -2.131724208809788
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 6001
# highest price: 48000
# strategy: buy and hold
# expected return: 0.24298722997256228
# sharpe ratio: -2.1229130760019412
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 6001
# highest price: 50000
# strategy: buy and hold
# expected return: 0.23971693089749607
# sharpe ratio: -2.119086196057614
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 6001
# highest price: 52000
# strategy: buy and hold
# expected return: 0.23003537396463314
# sharpe ratio: -2.109451350368155
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 6001
# highest price: 54000
# strategy: buy and hold
# expected return: 0.24584649631942007
# sharpe ratio: -2.188040389459155
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 6001
# highest price: 56000
# strategy: buy and hold
# expected return: 0.1748246210739484
# sharpe ratio: -2.3730931962066575
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 6001
# highest price: 58000
# strategy: buy and hold
# expected return: 0.16438204475004725
# sharpe ratio: -2.5199028778084487
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 8001
# highest price: 40000
# strategy: buy and hold
# expected return: 0.35495518160006007
# sharpe ratio: -1.5127580135367427
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 8001
# highest price: 42000
# strategy: buy and hold
# expected return: 0.34478144223423624
# sharpe ratio: -1.609376613848719
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 8001
# highest price: 44000
# strategy: buy and hold
# expected return: 0.2802950097556945
# sharpe ratio: -1.7540909209055005
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 8001
# highest price: 46000
# strategy: buy and hold
# expected return: 0.33335806685081143
# sharpe ratio: -1.6493436040212315
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 8001
# highest price: 48000
# strategy: buy and hold
# expected return: 0.2592253503406342
# sharpe ratio: -1.8163441572796943
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 8001
# highest price: 50000
# strategy: buy and hold
# expected return: 0.2312018133318903
# sharpe ratio: -1.958907841936417
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 8001
# highest price: 52000
# strategy: buy and hold
# expected return: 0.1872344318106881
# sharpe ratio: -2.1452598695370404
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 8001
# highest price: 54000
# strategy: buy and hold
# expected return: 0.21162817432837702
# sharpe ratio: -2.0312748852147053
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 8001
# highest price: 56000
# strategy: buy and hold
# expected return: 0.16604988966400797
# sharpe ratio: -2.06226742779923
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 26
# lowest price: 8001
# highest price: 58000
# strategy: buy and hold
# expected return: 0.1035139284724878
# sharpe ratio: -2.497341067780643
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 1
# highest price: 40000
# strategy: buy and hold
# expected return: 0.03287095478516047
# sharpe ratio: -27.62206575950838
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 1
# highest price: 42000
# strategy: buy and hold
# expected return: 0.04162267555284716
# sharpe ratio: -20.96804829897465
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 1
# highest price: 44000
# strategy: buy and hold
# expected return: 0.04438702143061699
# sharpe ratio: -20.720073113448446
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 1
# highest price: 46000
# strategy: buy and hold
# expected return: 0.042278248307754965
# sharpe ratio: -21.96092785689423
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 1
# highest price: 48000
# strategy: buy and hold
# expected return: 0.04416898116858158
# sharpe ratio: -21.757834662497146
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 1
# highest price: 50000
# strategy: buy and hold
# expected return: 0.03745122955664027
# sharpe ratio: -23.394813181644114
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 1
# highest price: 52000
# strategy: buy and hold
# expected return: 0.03392750093469839
# sharpe ratio: -23.735791562559047
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 1
# highest price: 54000
# strategy: buy and hold
# expected return: 0.030626368871081156
# sharpe ratio: -24.0046506024433
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 1
# highest price: 56000
# strategy: buy and hold
# expected return: 0.028737535084789396
# sharpe ratio: -24.642473762568947
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 1
# highest price: 58000
# strategy: buy and hold
# expected return: 0.025814072491595768
# sharpe ratio: -25.057406709065102
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 2001
# highest price: 40000
# strategy: buy and hold
# expected return: 0.2493153159434933
# sharpe ratio: -2.9450726477343205
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 2001
# highest price: 42000
# strategy: buy and hold
# expected return: 0.23666220522250517
# sharpe ratio: -3.1155107116139966
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 2001
# highest price: 44000
# strategy: buy and hold
# expected return: 0.20797594498951402
# sharpe ratio: -3.385214311265753
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 2001
# highest price: 46000
# strategy: buy and hold
# expected return: 0.21004818306742684
# sharpe ratio: -3.3839683882744853
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 2001
# highest price: 48000
# strategy: buy and hold
# expected return: 0.2175615477102938
# sharpe ratio: -3.206661970966905
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 2001
# highest price: 50000
# strategy: buy and hold
# expected return: 0.17338251935013588
# sharpe ratio: -3.7226058455806115
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 2001
# highest price: 52000
# strategy: buy and hold
# expected return: 0.17078305316142933
# sharpe ratio: -3.651759064293277
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 2001
# highest price: 54000
# strategy: buy and hold
# expected return: 0.1937373461689878
# sharpe ratio: -3.3181570155431586
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 2001
# highest price: 56000
# strategy: buy and hold
# expected return: 0.1862067462075325
# sharpe ratio: -3.1946016776107116
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 2001
# highest price: 58000
# strategy: buy and hold
# expected return: 0.1441327785095636
# sharpe ratio: -3.5449067365771394
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 4001
# highest price: 40000
# strategy: buy and hold
# expected return: 0.34192907832870767
# sharpe ratio: -1.9415415238589924
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 4001
# highest price: 42000
# strategy: buy and hold
# expected return: 0.35273122172290167
# sharpe ratio: -1.8524830071669702
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 4001
# highest price: 44000
# strategy: buy and hold
# expected return: 0.29544581477536425
# sharpe ratio: -2.1119132454736906
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 4001
# highest price: 46000
# strategy: buy and hold
# expected return: 0.29708462728381263
# sharpe ratio: -2.0663439232759915
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 4001
# highest price: 48000
# strategy: buy and hold
# expected return: 0.2780527448540882
# sharpe ratio: -2.228967177250937
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 4001
# highest price: 50000
# strategy: buy and hold
# expected return: 0.23796217526732785
# sharpe ratio: -2.398113522853975
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 4001
# highest price: 52000
# strategy: buy and hold
# expected return: 0.2951707385369717
# sharpe ratio: -2.0920498968871044
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 4001
# highest price: 54000
# strategy: buy and hold
# expected return: 0.24525404923814714
# sharpe ratio: -2.2991833938285877
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 4001
# highest price: 56000
# strategy: buy and hold
# expected return: 0.18588794395912486
# sharpe ratio: -2.605179772669621
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 4001
# highest price: 58000
# strategy: buy and hold
# expected return: 0.2116164494016794
# sharpe ratio: -2.38779513184476
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 6001
# highest price: 40000
# strategy: buy and hold
# expected return: 0.39598926213355684
# sharpe ratio: -1.489086186947458
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 6001
# highest price: 42000
# strategy: buy and hold
# expected return: 0.36960353784032934
# sharpe ratio: -1.5330971016983466
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 6001
# highest price: 44000
# strategy: buy and hold
# expected return: 0.3143918219066079
# sharpe ratio: -1.7631791331624085
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 6001
# highest price: 46000
# strategy: buy and hold
# expected return: 0.3420948810236064
# sharpe ratio: -1.683593239673452
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 6001
# highest price: 48000
# strategy: buy and hold
# expected return: 0.2795535141693252
# sharpe ratio: -1.8134343814637515
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 6001
# highest price: 50000
# strategy: buy and hold
# expected return: 0.27234282100882595
# sharpe ratio: -1.9502840618659028
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 6001
# highest price: 52000
# strategy: buy and hold
# expected return: 0.25759370585183167
# sharpe ratio: -1.8364092014587852
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 6001
# highest price: 54000
# strategy: buy and hold
# expected return: 0.22137484627491283
# sharpe ratio: -2.137388527372918
# *--------------------------------*
# index: 0
# unit: 1
# grid number: 28
# lowest price: 6001
# highest price: 56000
# strategy: buy and hold
# expected return: 0.18050601057946733
# sharpe ratio: -2.05647144304227
# *--------------------------------*
# index: 0
# unit: 1
# ...
# lowest price: 4001
# highest price: 42000
# strategy: buy and hold
# expected return: 352.2296362737771
# sharpe ratio: 0.48062803451663755
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 36
# lowest price: 4001
# highest price: 44000
# strategy: buy and hold
# expected return: 329.368160263111
# sharpe ratio: 0.4879238269155947
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 36
# lowest price: 4001
# highest price: 46000
# strategy: buy and hold
# expected return: 272.1631934457258
# sharpe ratio: 0.4482617497004089
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 36
# lowest price: 4001
# highest price: 48000
# strategy: buy and hold
# expected return: 281.88762978655467
# sharpe ratio: 0.4578124227872905
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 36
# lowest price: 4001
# highest price: 50000
# strategy: buy and hold
# expected return: 416.32018607040766
# sharpe ratio: 0.4265367284246309
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 36
# lowest price: 4001
# highest price: 52000
# strategy: buy and hold
# expected return: 332.5374429178677
# sharpe ratio: 0.5027494597453903
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 36
# lowest price: 4001
# highest price: 54000
# strategy: buy and hold
# expected return: 271.36977551766955
# sharpe ratio: 0.48408816167903457
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 36
# lowest price: 4001
# highest price: 56000
# strategy: buy and hold
# expected return: 299.5371105140134
# sharpe ratio: 0.4803644224450395
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 36
# lowest price: 4001
# highest price: 58000
# strategy: buy and hold
# expected return: 288.4468060183996
# sharpe ratio: 0.4670992079632979
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 36
# lowest price: 6001
# highest price: 40000
# strategy: buy and hold
# expected return: 368.5840695946086
# sharpe ratio: 0.4283583993243922
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 36
# lowest price: 6001
# highest price: 42000
# strategy: buy and hold
# expected return: 304.97665813056227
# sharpe ratio: 0.3652831356820623
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 36
# lowest price: 6001
# highest price: 44000
# strategy: buy and hold
# expected return: 323.54590224339637
# sharpe ratio: 0.40429840823374846
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 36
# lowest price: 6001
# highest price: 46000
# strategy: buy and hold
# expected return: 380.35115991065385
# sharpe ratio: 0.4364904295731405
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 36
# lowest price: 6001
# highest price: 48000
# strategy: buy and hold
# expected return: 346.4153564909509
# sharpe ratio: 0.4738052577489357
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 36
# lowest price: 6001
# highest price: 50000
# strategy: buy and hold
# expected return: 325.18458034580146
# sharpe ratio: 0.4772091298965391
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 36
# lowest price: 6001
# highest price: 52000
# strategy: buy and hold
# expected return: 394.6691017251271
# sharpe ratio: 0.35602693198228064
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 36
# lowest price: 6001
# highest price: 54000
# strategy: buy and hold
# expected return: 305.036605974583
# sharpe ratio: 0.4579730774859679
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 36
# lowest price: 6001
# highest price: 56000
# strategy: buy and hold
# expected return: 324.0527085619654
# sharpe ratio: 0.4665535391417927
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 36
# lowest price: 6001
# highest price: 58000
# strategy: buy and hold
# expected return: 321.5590885848251
# sharpe ratio: 0.41103380487546914
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 36
# lowest price: 8001
# highest price: 40000
# strategy: buy and hold
# expected return: 271.18009985778093
# sharpe ratio: 0.4285766787897618
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 36
# lowest price: 8001
# highest price: 42000
# strategy: buy and hold
# expected return: 231.96761214612724
# sharpe ratio: 0.46119675259253523
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 36
# lowest price: 8001
# highest price: 44000
# strategy: buy and hold
# expected return: 231.2135262824749
# sharpe ratio: 0.46044746546905
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 36
# lowest price: 8001
# highest price: 46000
# strategy: buy and hold
# expected return: 186.99537331385923
# sharpe ratio: 0.4708351360815488
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 36
# lowest price: 8001
# highest price: 48000
# strategy: buy and hold
# expected return: 169.39944068151078
# sharpe ratio: 0.40866029106778123
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 36
# lowest price: 8001
# highest price: 50000
# strategy: buy and hold
# expected return: 210.2312976200117
# sharpe ratio: 0.44421196190520956
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 36
# lowest price: 8001
# highest price: 52000
# strategy: buy and hold
# expected return: 209.4875816441045
# sharpe ratio: 0.44309682002166073
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 36
# lowest price: 8001
# highest price: 54000
# strategy: buy and hold
# expected return: 291.5518874792715
# sharpe ratio: 0.36608746805505893
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 36
# lowest price: 8001
# highest price: 56000
# strategy: buy and hold
# expected return: 241.63151210525643
# sharpe ratio: 0.3902031510533288
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 36
# lowest price: 8001
# highest price: 58000
# strategy: buy and hold
# expected return: 238.42049346606578
# sharpe ratio: 0.38577407538125685
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 1
# highest price: 40000
# strategy: buy and hold
# expected return: 245.11382044855532
# sharpe ratio: 0.44279196014074673
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 1
# highest price: 42000
# strategy: buy and hold
# expected return: 143.4872629126893
# sharpe ratio: 0.45926827177304524
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 1
# highest price: 44000
# strategy: buy and hold
# expected return: 165.40720818872873
# sharpe ratio: 0.37469729419948417
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 1
# highest price: 46000
# strategy: buy and hold
# expected return: 168.53883492665798
# sharpe ratio: 0.3808417700325266
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 1
# highest price: 48000
# strategy: buy and hold
# expected return: 181.731575937562
# sharpe ratio: 0.41504965958004225
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 1
# highest price: 50000
# strategy: buy and hold
# expected return: 188.1102994025789
# sharpe ratio: 0.4407965351072011
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 1
# highest price: 52000
# strategy: buy and hold
# expected return: 193.6756789664866
# sharpe ratio: 0.45778052984781686
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 1
# highest price: 54000
# strategy: buy and hold
# expected return: 196.92753487457875
# sharpe ratio: 0.46994665502541766
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 1
# highest price: 56000
# strategy: buy and hold
# expected return: 259.24824691776104
# sharpe ratio: 0.46722065665542895
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 1
# highest price: 58000
# strategy: buy and hold
# expected return: 145.52735442121576
# sharpe ratio: 0.46379533370589326
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 2001
# highest price: 40000
# strategy: buy and hold
# expected return: 281.66961019048335
# sharpe ratio: 0.5132461144297912
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 2001
# highest price: 42000
# strategy: buy and hold
# expected return: 360.2129808869419
# sharpe ratio: 0.49931287576232
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 2001
# highest price: 44000
# strategy: buy and hold
# expected return: 390.2598203952618
# sharpe ratio: 0.49682277035130296
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 2001
# highest price: 46000
# strategy: buy and hold
# expected return: 269.91170590325004
# sharpe ratio: 0.4486692696439089
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 2001
# highest price: 48000
# strategy: buy and hold
# expected return: 300.16573350151947
# sharpe ratio: 0.5284798446025297
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 2001
# highest price: 50000
# strategy: buy and hold
# expected return: 360.4222122422632
# sharpe ratio: 0.5087565622423981
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 2001
# highest price: 52000
# strategy: buy and hold
# expected return: 342.9918629579212
# sharpe ratio: 0.5490252899834702
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 2001
# highest price: 54000
# strategy: buy and hold
# expected return: 342.33463367828875
# sharpe ratio: 0.4725986768411769
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 2001
# highest price: 56000
# strategy: buy and hold
# expected return: 273.6791169584299
# sharpe ratio: 0.4519383197448736
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 2001
# highest price: 58000
# strategy: buy and hold
# expected return: 309.9889899670198
# sharpe ratio: 0.499369125381167
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 4001
# highest price: 40000
# strategy: buy and hold
# expected return: 374.7285860724053
# sharpe ratio: 0.45244351685902306
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 4001
# highest price: 42000
# strategy: buy and hold
# expected return: 348.62635906398276
# sharpe ratio: 0.47355119496885
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 4001
# highest price: 44000
# strategy: buy and hold
# expected return: 339.2629502653907
# sharpe ratio: 0.46326181235318065
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 4001
# highest price: 46000
# strategy: buy and hold
# expected return: 302.5093155346117
# sharpe ratio: 0.5193912790417541
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 4001
# highest price: 48000
# strategy: buy and hold
# expected return: 351.9805316645022
# sharpe ratio: 0.48033703314583776
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 4001
# highest price: 50000
# strategy: buy and hold
# expected return: 323.7061086280975
# sharpe ratio: 0.47932141978233866
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 4001
# highest price: 52000
# strategy: buy and hold
# expected return: 298.365046951921
# sharpe ratio: 0.43815708361102335
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 4001
# highest price: 54000
# strategy: buy and hold
# expected return: 291.8572989268513
# sharpe ratio: 0.42981484435148315
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 4001
# highest price: 56000
# strategy: buy and hold
# expected return: 291.44822124563547
# sharpe ratio: 0.4699228358398777
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 4001
# highest price: 58000
# strategy: buy and hold
# expected return: 430.02731140960384
# sharpe ratio: 0.427505782242021
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 6001
# highest price: 40000
# strategy: buy and hold
# expected return: 553.7222261932314
# sharpe ratio: 0.4227674171939385
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 6001
# highest price: 42000
# strategy: buy and hold
# expected return: 404.8262805200658
# sharpe ratio: 0.42963268348155054
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 6001
# highest price: 44000
# strategy: buy and hold
# expected return: 379.60143013146705
# sharpe ratio: 0.4363510326459336
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 6001
# highest price: 46000
# strategy: buy and hold
# expected return: 289.8647721318982
# sharpe ratio: 0.3776887709807084
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 6001
# highest price: 48000
# strategy: buy and hold
# expected return: 343.6856610017578
# sharpe ratio: 0.3994514416648524
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 6001
# highest price: 50000
# strategy: buy and hold
# expected return: 374.928856622606
# sharpe ratio: 0.4271419083576896
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 6001
# highest price: 52000
# strategy: buy and hold
# expected return: 373.126348863382
# sharpe ratio: 0.4322469036068295
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 6001
# highest price: 54000
# strategy: buy and hold
# expected return: 331.2905337276193
# sharpe ratio: 0.4841531496392741
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 6001
# highest price: 56000
# strategy: buy and hold
# expected return: 325.46058632980765
# sharpe ratio: 0.4775357708612007
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 6001
# highest price: 58000
# strategy: buy and hold
# expected return: 399.9408174458573
# sharpe ratio: 0.3615660597457084
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 8001
# highest price: 40000
# strategy: buy and hold
# expected return: 371.7168097250987
# sharpe ratio: 0.3565952011502105
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 8001
# highest price: 42000
# strategy: buy and hold
# expected return: 268.2554839585076
# sharpe ratio: 0.4163897145876914
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 8001
# highest price: 44000
# strategy: buy and hold
# expected return: 268.20612796562364
# sharpe ratio: 0.4252714406179786
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 8001
# highest price: 46000
# strategy: buy and hold
# expected return: 231.98516012241765
# sharpe ratio: 0.46121407953146903
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 8001
# highest price: 48000
# strategy: buy and hold
# expected return: 231.3318203706345
# sharpe ratio: 0.46056561514063526
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 8001
# highest price: 50000
# strategy: buy and hold
# expected return: 229.78199262049168
# sharpe ratio: 0.4585261991652838
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 8001
# highest price: 52000
# strategy: buy and hold
# expected return: 169.72451238765663
# sharpe ratio: 0.40927490818957485
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 8001
# highest price: 54000
# strategy: buy and hold
# expected return: 203.6200221384469
# sharpe ratio: 0.4235513757413978
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 8001
# highest price: 56000
# strategy: buy and hold
# expected return: 210.02451541537698
# sharpe ratio: 0.44390270354677525
# *--------------------------------*
# index: 0
# unit: 10001
# grid number: 38
# lowest price: 8001
# highest price: 58000
# strategy: buy and hold
# expected return: 209.39366945980936
# sharpe ratio: 0.4429554432246243

# %%
print(np.argmax(expected), np.argmax(sharpe))
# Out:
# 3982 6510

# %%
index = 0
u = 0
for unit in range(1, 10501, 500):
    g = 0
    for grid_number in range(20, 40, 2):
        l = 0
        for lowest_price in range(1, 10000, 2000):
            h = 0
            for highest_price in range(40000, 60000, 2000):
                if (index == 3982 or index == 6510):
                    print(unit, grid_number, lowest_price, highest_price)
                    print(u, g, l, h)
                index += 1
                h += 1
            l += 1
        g += 1
    u += 1
# Out:
# 3501 38 6001 44000
# 7 9 3 2
# 6501 20 2001 40000
# 13 0 1 0

# %%
grid_parameters = {
    "name":"grid",                                    ## str
    "start_money" : 1000.0,                           ## float    
    "start_storage" : 0.0,                            ## float
    "trading_fee_rate" : 0.002,                       ## float
    "unit" : 0.005,                                   ## float
    "grid_number" : 20,                               ## int  
    "equal_Diff_or_Ratio" : "RATIO",                  ## "DIFF", "RATIO"
    "trading_logistic":"both",                        ## "long", "short", "both"
    "initial_setup":{"type":"None", "portion":0.0},   ## "type": "long", "short" or "None". "portion" : float
    "lowest_price" : 1.0,                             ## float
    "highest_price" : 60000.0                         ## float
}

grid_parameters["unit"] = 6501/100000
grid_parameters["grid_number"] = 20
grid_parameters["lowest_price"] = 2001
grid_parameters["highest_price"] = 40000

myGrid = Strategies.Grid(grid_parameters)
sharpe_ratio, expected_return = Strategy_Analysis_Tool.Analysis_tool.Shape_Ratio(myGrid, df, 0.02, window_size=10000, window_off=1000)
print("*--------------------------------*")
print("unit:", myGrid.unit)
print("grid number:", myGrid.grid_number)
print("lowest price:", myGrid.lowest_price)
print("highest price:", myGrid.highest_price)
print("strategy:", myGrid.name)
print("expected return:", expected_return * 100)
print("sharpe ratio:", sharpe_ratio)
# Out:
# *--------------------------------*
# unit: 0.06501
# grid number: 20
# lowest price: 2001
# highest price: 40000
# strategy: grid
# expected return: 342.4370802831899
# sharpe ratio: 0.6681209308675267

# %%
Expected_Return = np.array(expected)
Sharpe_Ratio = np.array(sharpe)
R = Expected_Return.reshape([21, 10, 5, 10])
S = Sharpe_Ratio.reshape([21,10, 5, 10])

# %%
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
 
low = list(range(1, 10000, 2000))
high = list(range(40000, 60000, 2000))
X, Y = np.meshgrid(low, high)

three_dim_R = R[7, 9, :, :]
Z = np.transpose(three_dim_R) * 100
print(np.max(Z))

fig = plt.figure(figsize=(12,10))
ax = plt.axes(projection ='3d')
ax.scatter(44000, 6001, np.max(Z))
ax.set_title('Lowest and highest price with Return')
surf = ax.plot_surface(Y, X, Z, cmap = plt.cm.cividis)
ax.set_xlabel("Highest Price")
ax.set_ylabel("Lowest Price")
ax.set_zlabel("Expected Return (%)")
# Out:
# 614.5862752204672
# Text(0.5, 0, 'Expected Return (%)')

# %%
unit = list(range(1, 10501, 500))
grid_number = list(range(20, 40, 2))
X, Y = np.meshgrid(unit, grid_number)
X = np.array(X) / 100000

three_dim_R = R[:, :, 3, 2]
Z = np.transpose(three_dim_R) * 100
print(np.max(Z))

fig = plt.figure(figsize=(12,10))
ax = plt.axes(projection ='3d')
ax.scatter(38, 0.03501, np.max(Z))
ax.set_title('Grid number and unit with Return')
surf = ax.plot_surface(Y, X, Z, cmap = plt.cm.cividis)
ax.set_xlabel("grid number")
ax.set_ylabel("unit")
ax.set_zlabel("Expected Return (%)")
# Out:
# 614.5862752204672
# Text(0.5, 0, 'Expected Return (%)')

# %%
high = list(range(40000, 60000, 2000))
grid_number = list(range(20, 40, 2))
X, Y = np.meshgrid(high, grid_number)

three_dim_R = R[7, :, 3, :]
# Z = np.transpose(three_dim_R) * 100
Z = three_dim_R * 100
print(np.max(Z))

fig = plt.figure(figsize=(12,10))
ax = plt.axes(projection ='3d')
ax.set_title('Grid number and highest price with Return')
ax.scatter(44000, 38, np.max(Z))
surf = ax.plot_surface(X, Y, Z, cmap = plt.cm.cividis)
ax.set_xlabel("highest price")
ax.set_ylabel("grid number")
ax.set_zlabel("Expected Return (%)")
# Out:
# 614.5862752204672
# Text(0.5, 0, 'Expected Return (%)')

# %%
low = list(range(1, 10000, 2000))
high = list(range(40000, 60000, 2000))
X, Y = np.meshgrid(low, high)

three_dim_R = S[13, 0, :, :]
Z = np.transpose(three_dim_R)
print(np.max(Z))

fig = plt.figure(figsize=(12,10))
ax = plt.axes(projection ='3d')
ax.set_title('Lowest and highest price with Sharpe Ratio')
surf = ax.plot_surface(Y, X, Z, cmap = plt.cm.cividis)
ax.set_xlabel("Highest Price")
ax.set_ylabel("Lowest Price")
ax.scatter(40000, 2001, np.max(Z))
ax.set_zlabel("Sharpe Ratio")
# Out:
# 0.6681209308675267
# Text(0.5, 0, 'Sharpe Ratio')

# %%
unit = list(range(1, 10501, 500))
grid_number = list(range(20, 40, 2))
X, Y = np.meshgrid(unit, grid_number)
X = np.array(X) / 100000

three_dim_R = S[:, :, 1, 0]
Z = np.transpose(three_dim_R)
print(np.max(Z))


fig = plt.figure(figsize=(12,10))
ax = plt.axes(projection ='3d')
ax.scatter(20, 0.06501, np.max(Z))
ax.set_title('Grid number and unit with Sharpe Ratio')
surf = ax.plot_surface(Y, X, Z, cmap = plt.cm.cividis)
ax.set_xlabel("grid number")
ax.set_ylabel("unit")
ax.set_zlabel("Sharpe Ratio")
# Out:
# 0.6681209308675267
# Text(0.5, 0, 'Sharpe Ratio')

# %%
high = list(range(40000, 60000, 2000))
grid_number = list(range(20, 40, 2))
X, Y = np.meshgrid(high, grid_number)

three_dim_R = S[13, :, 1, :]
# Z = np.transpose(three_dim_R)
Z = three_dim_R
print(np.max(Z))

fig = plt.figure(figsize=(12,10))
ax = plt.axes(projection ='3d')
ax.set_title('Grid number and highest price with Sharpe Ratio')
surf = ax.plot_surface(Y, X, Z, cmap = plt.cm.cividis)
ax.scatter(20, 40000, np.max(Z))
ax.set_xlabel("grid number")
ax.set_ylabel("highest price")
ax.set_zlabel("Sharpe Ratio")
# Out:
# 0.6681209308675267
# Text(0.5, 0, 'Sharpe Ratio')
